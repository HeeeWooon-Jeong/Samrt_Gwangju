# %%
#!pip install missingno
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import missingno as msno
from sklearn.tree import DecisionTreeClassifier

# %%
train = pd.read_csv("train_fix1.csv")
test = pd.read_csv("test_fix1.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6999 entries, 0 to 6998
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Warehouse_block      6999 non-null   object
#  1   Mode_of_Shipment     6999 non-null   object
#  2   Customer_care_calls  5423 non-null   float64
#  3   Customer_rating      6999 non-null   int64
#  4   Cost_of_the_Product  6999 non-null   int64
#  5   Prior_purchases      6049 non-null   float64
#  6   Product_importance   6999 non-null   object
#  7   Discount_offered     3468 non-null   float64
#  8   Weight_in_gms        6553 non-null   float64
#  9   Reached.on.Time_Y.N  6999 non-null   int64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 546.9+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Warehouse_block      4000 non-null   object
#  1   Mode_of_Shipment     4000 non-null   object
#  2   Customer_care_calls  3144 non-null   float64
#  3   Customer_rating      4000 non-null   int64
#  4   Cost_of_the_Product  4000 non-null   int64
#  5   Prior_purchases      3633 non-null   float64
#  6   Product_importance   4000 non-null   object
#  7   Discount_offered     2085 non-null   float64
#  8   Weight_in_gms        4000 non-null   object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 281.4+ KB

# %% [markdown]
# # Train 결측치 수정

# %% [markdown]
# # Customer_care_calls 0 으로 채움

# %%
# Customer_care_calls 0 으로 채움
train['Customer_care_calls'].fillna(0, inplace=True)  
test['Customer_care_calls'].fillna(0, inplace=True)

# %% [markdown]
# # Discount_offered 결측치 채움

# %%
# 결측치를 75% 값(10)으로, 25% 값(7)으로 채우기
train['Discount_offered'].fillna(train['Discount_offered'].quantile(0.75), inplace=True)  # 75% 값(10)으로 결측치 채우기
train['Discount_offered'].fillna(train['Discount_offered'].quantile(0.25), inplace=True)  # 25% 값(7)으로 결측치 채우기
# 결측치를 75% 값(10)으로, 25% 값(7)으로 채우기
test['Discount_offered'].fillna(test['Discount_offered'].quantile(0.75), inplace=True)  # 75% 값(10)으로 결측치 채우기
test['Discount_offered'].fillna(test['Discount_offered'].quantile(0.25), inplace=True)  # 25% 값(7)으로 결측치 채우기

# %% [markdown]
# # Prior_purchases 결측치 채움 - 최빈값

# %%
train['Prior_purchases'].fillna(train['Prior_purchases'].mode()[0], inplace=True)  

test['Prior_purchases'].fillna(test['Prior_purchases'].mode()[0], inplace=True)

# %% [markdown]
# # Mode_of_Shipment - 100% 정답이기 때문에 ship으로 떄려박자

# %%
train['Mode_of_Shipment'].replace('?', 'Ship', inplace=True)
test['Mode_of_Shipment'].replace('?', 'Ship', inplace=True)

# %% [markdown]
# # Product_importance ? 값 대체 반 반 안되서  medium으로

# %%
train['Product_importance'].replace('?', 'medium', inplace=True)
test['Product_importance'].replace('?', 'medium', inplace=True)

# %% [markdown]
# # Weight_in_gms ? 3000 으로 대체(09_12test참고)
# # 결측치도 존재
# - train은 2000~4000대 까지 값이 있으나  test는 존재하지않음
# - 평균값 4189 넣어보고 - 65
# - 3000대 값 넣어보기

# %%
# 이상치 해결
train['Weight_in_gms'].replace('?', 3000, inplace=True)
# 결측치 해결
train['Weight_in_gms'].fillna(train['Weight_in_gms'].mode()[0], inplace=True)  
# 타입 변경
train['Weight_in_gms'] = train['Weight_in_gms'].astype('int64')

# 이상치 해결
test['Weight_in_gms'].replace('?', 3000, inplace=True)
# 결측치 해결
test['Weight_in_gms'].fillna(test['Weight_in_gms'].mode()[0], inplace=True)  
# 타입 변경
test['Weight_in_gms'] = test['Weight_in_gms'].astype('int64')

# %%
X_train.corr()
# Out:
#                            Customer_care_calls  Customer_rating  \
# Customer_care_calls                   1.000000         0.009423
# Customer_rating                       0.009423         1.000000
# Cost_of_the_Product                   0.144350         0.006108
# Discount_offered                     -0.055720        -0.011650
# Weight_in_gms                        -0.090415         0.012086
# Reached.on.Time_Y.N                  -0.061375         0.001127
# Mode_of_Shipment_Flight               0.013443        -0.000894
# Mode_of_Shipment_Road                 0.011019        -0.005619
# Mode_of_Shipment_Ship                -0.019065         0.005105
# Product_importance_high               0.030049        -0.003362
# Product_importance_low               -0.034266         0.006696
# Product_importance_medium            -0.011297        -0.000318
#
#                            Cost_of_the_Product  Discount_offered  \
# Customer_care_calls                   0.144350         -0.055720
# Customer_rating                       0.006108         -0.011650
# Cost_of_the_Product                   1.000000         -0.096344
# Discount_offered                     -0.096344          1.000000
# Weight_in_gms                        -0.118035         -0.246152
# Reached.on.Time_Y.N                  -0.068100          0.276998
# Mode_of_Shipment_Flight              -0.017730         -0.003290
# Mode_of_Shipment_Road                 0.020011          0.003469
# Mode_of_Shipment_Ship                -0.001985         -0.000177
# Product_importance_high               0.041745         -0.011970
# Product_importance_low               -0.033712          0.030130
# Product_importance_medium            -0.023373         -0.004609
#
#                            Weight_in_gms  Reached.on.Time_Y.N  \
# Customer_care_calls            -0.090415            -0.061375
# Customer_rating                 0.012086             0.001127
# Cost_of_the_Product            -0.118035            -0.068100
# Discount_offered               -0.246152             0.276998
# Weight_in_gms                   1.000000            -0.254428
# Reached.on.Time_Y.N            -0.254428             1.000000
# Mode_of_Shipment_Flight        -0.003449             0.005365
# Mode_of_Shipment_Road          -0.014444             0.003348
# Mode_of_Shipment_Ship           0.014015            -0.006785
# Product_importance_high        -0.081980            -0.012308
# Product_importance_low          0.074139             0.024041
# Product_importance_medium       0.041515            -0.000904
#
#                            Mode_of_Shipment_Flight  Mode_of_Shipment_Road  \
# Customer_care_calls                       0.013443               0.011019
# Customer_rating                          -0.000894              -0.005619
# Cost_of_the_Product                      -0.017730               0.020011
# Discount_offered                         -0.003290               0.003469
# Weight_in_gms                            -0.003449              -0.014444
# Reached.on.Time_Y.N                       0.005365               0.003348
# Mode_of_Shipment_Flight                   1.000000              -0.178060
# Mode_of_Shipment_Road                    -0.178060               1.000000
# Mode_of_Shipment_Ship                    -0.634623              -0.647472
# Product_importance_high                  -0.010488              -0.001782
# Product_importance_low                    0.009820               0.015527
# Product_importance_medium                 0.005126              -0.006789
#
#                            Mode_of_Shipment_Ship  Product_importance_high  \
# Customer_care_calls                    -0.019065                 0.030049
# Customer_rating                         0.005105                -0.003362
# Cost_of_the_Product                    -0.001985                 0.041745
# Discount_offered                       -0.000177                -0.011970
# Weight_in_gms                           0.014015                -0.081980
# Reached.on.Time_Y.N                    -0.006785                -0.012308
# Mode_of_Shipment_Flight                -0.634623                -0.010488
# Mode_of_Shipment_Road                  -0.647472                -0.001782
# Mode_of_Shipment_Ship                   1.000000                 0.009523
# Product_importance_high                 0.009523                 1.000000
# Product_importance_low                 -0.019800                -0.285978
# Product_importance_medium               0.001362                -0.848206
#
#                            Product_importance_low  Product_importance_medium
# Customer_care_calls                     -0.034266                  -0.011297
# Customer_rating                          0.006696                  -0.000318
# Cost_of_the_Product                     -0.033712                  -0.023373
# Discount_offered                         0.030130                  -0.004609
# Weight_in_gms                            0.074139                   0.041515
# Reached.on.Time_Y.N                      0.024041                  -0.000904
# Mode_of_Shipment_Flight                  0.009820                   0.005126
# Mode_of_Shipment_Road                    0.015527                  -0.006789
# Mode_of_Shipment_Ship                   -0.019800                   0.001362
# Product_importance_high                 -0.285978                  -0.848206
# Product_importance_low                   1.000000                  -0.264976
# Product_importance_medium               -0.264976                   1.000000

# %%
corr_matrix = X_train.corr()
reordered_columns = ['Reached.on.Time_Y.N'] + [col for col in corr_matrix.columns if col != 'Reached.on.Time_Y.N']
corr_matrix = corr_matrix[reordered_columns]
corr_matrix
# Out:
#                            Reached.on.Time_Y.N  Customer_care_calls  \
# Customer_care_calls                  -0.061375             1.000000
# Customer_rating                       0.001127             0.009423
# Cost_of_the_Product                  -0.068100             0.144350
# Discount_offered                      0.276998            -0.055720
# Weight_in_gms                        -0.254428            -0.090415
# Reached.on.Time_Y.N                   1.000000            -0.061375
# Mode_of_Shipment_Flight               0.005365             0.013443
# Mode_of_Shipment_Road                 0.003348             0.011019
# Mode_of_Shipment_Ship                -0.006785            -0.019065
# Product_importance_high              -0.012308             0.030049
# Product_importance_low                0.024041            -0.034266
# Product_importance_medium            -0.000904            -0.011297
#
#                            Customer_rating  Cost_of_the_Product  \
# Customer_care_calls               0.009423             0.144350
# Customer_rating                   1.000000             0.006108
# Cost_of_the_Product               0.006108             1.000000
# Discount_offered                 -0.011650            -0.096344
# Weight_in_gms                     0.012086            -0.118035
# Reached.on.Time_Y.N               0.001127            -0.068100
# Mode_of_Shipment_Flight          -0.000894            -0.017730
# Mode_of_Shipment_Road            -0.005619             0.020011
# Mode_of_Shipment_Ship             0.005105            -0.001985
# Product_importance_high          -0.003362             0.041745
# Product_importance_low            0.006696            -0.033712
# Product_importance_medium        -0.000318            -0.023373
#
#                            Discount_offered  Weight_in_gms  \
# Customer_care_calls               -0.055720      -0.090415
# Customer_rating                   -0.011650       0.012086
# Cost_of_the_Product               -0.096344      -0.118035
# Discount_offered                   1.000000      -0.246152
# Weight_in_gms                     -0.246152       1.000000
# Reached.on.Time_Y.N                0.276998      -0.254428
# Mode_of_Shipment_Flight           -0.003290      -0.003449
# Mode_of_Shipment_Road              0.003469      -0.014444
# Mode_of_Shipment_Ship             -0.000177       0.014015
# Product_importance_high           -0.011970      -0.081980
# Product_importance_low             0.030130       0.074139
# Product_importance_medium         -0.004609       0.041515
#
#                            Mode_of_Shipment_Flight  Mode_of_Shipment_Road  \
# Customer_care_calls                       0.013443               0.011019
# Customer_rating                          -0.000894              -0.005619
# Cost_of_the_Product                      -0.017730               0.020011
# Discount_offered                         -0.003290               0.003469
# Weight_in_gms                            -0.003449              -0.014444
# Reached.on.Time_Y.N                       0.005365               0.003348
# Mode_of_Shipment_Flight                   1.000000              -0.178060
# Mode_of_Shipment_Road                    -0.178060               1.000000
# Mode_of_Shipment_Ship                    -0.634623              -0.647472
# Product_importance_high                  -0.010488              -0.001782
# Product_importance_low                    0.009820               0.015527
# Product_importance_medium                 0.005126              -0.006789
#
#                            Mode_of_Shipment_Ship  Product_importance_high  \
# Customer_care_calls                    -0.019065                 0.030049
# Customer_rating                         0.005105                -0.003362
# Cost_of_the_Product                    -0.001985                 0.041745
# Discount_offered                       -0.000177                -0.011970
# Weight_in_gms                           0.014015                -0.081980
# Reached.on.Time_Y.N                    -0.006785                -0.012308
# Mode_of_Shipment_Flight                -0.634623                -0.010488
# Mode_of_Shipment_Road                  -0.647472                -0.001782
# Mode_of_Shipment_Ship                   1.000000                 0.009523
# Product_importance_high                 0.009523                 1.000000
# Product_importance_low                 -0.019800                -0.285978
# Product_importance_medium               0.001362                -0.848206
#
#                            Product_importance_low  Product_importance_medium
# Customer_care_calls                     -0.034266                  -0.011297
# Customer_rating                          0.006696                  -0.000318
# Cost_of_the_Product                     -0.033712                  -0.023373
# Discount_offered                         0.030130                  -0.004609
# Weight_in_gms                            0.074139                   0.041515
# Reached.on.Time_Y.N                      0.024041                  -0.000904
# Mode_of_Shipment_Flight                  0.009820                   0.005126
# Mode_of_Shipment_Road                    0.015527                  -0.006789
# Mode_of_Shipment_Ship                   -0.019800                   0.001362
# Product_importance_high                 -0.285978                  -0.848206
# Product_importance_low                   1.000000                  -0.264976
# Product_importance_medium               -0.264976                   1.000000

# %% [markdown]
# # 원핫 인코딩

# %%
# 원핫 인코딩
X_train = pd.get_dummies(train)
X_test = pd.get_dummies(test)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6999 entries, 0 to 6998
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer_care_calls        6999 non-null   float64
#  1   Customer_rating            6999 non-null   int64
#  2   Cost_of_the_Product        6999 non-null   int64
#  3   Prior_purchases            6999 non-null   float64
#  4   Discount_offered           6999 non-null   float64
#  5   Weight_in_gms              6999 non-null   int64
#  6   Reached.on.Time_Y.N        6999 non-null   int64
#  7   Warehouse_block_A          6999 non-null   uint8
#  8   Warehouse_block_B          6999 non-null   uint8
#  9   Warehouse_block_C          6999 non-null   uint8
#  10  Warehouse_block_D          6999 non-null   uint8
#  11  Warehouse_block_F          6999 non-null   uint8
#  12  Mode_of_Shipment_Flight    6999 non-null   uint8
#  13  Mode_of_Shipment_Road      6999 non-null   uint8
#  14  Mode_of_Shipment_Ship      6999 non-null   uint8
#  15  Product_importance_high    6999 non-null   uint8
#  16  Product_importance_low     6999 non-null   uint8
#  17  Product_importance_medium  6999 non-null   uint8
# dtypes: float64(3), int64(4), uint8(11)
# memory usage: 458.1 KB

# %%
X_train.describe()
# Out:
#        Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count          6999.000000      6999.000000          6999.000000
# mean              3.141592         2.996285           210.055008
# std               1.964630         1.410161            48.220091
# min               0.000000         1.000000            96.000000
# 25%               2.000000         2.000000           169.000000
# 50%               4.000000         3.000000           214.000000
# 75%               5.000000         4.000000           251.000000
# max               7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N  \
# count      6999.000000       6999.000000    6999.000000          6999.000000
# mean          3.498071         11.619803    3510.879840             0.594656
# std           1.436854         11.428752    1680.168612             0.490993
# min           2.000000          1.000000    1001.000000             0.000000
# 25%           3.000000          7.000000    1674.000000             0.000000
# 50%           3.000000         10.000000    4064.000000             1.000000
# 75%           4.000000         10.000000    5005.000000             1.000000
# max          10.000000         65.000000    7846.000000             1.000000
#
#        Warehouse_block_A  Warehouse_block_B  Warehouse_block_C  \
# count        6999.000000        6999.000000        6999.000000
# mean            0.167738           0.166024           0.169167
# std             0.373660           0.372129           0.374926
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        Warehouse_block_D  Warehouse_block_F  Mode_of_Shipment_Flight  \
# count        6999.000000        6999.000000              6999.000000
# mean            0.166881           0.330190                 0.148593
# std             0.372896           0.470315                 0.355712
# min             0.000000           0.000000                 0.000000
# 25%             0.000000           0.000000                 0.000000
# 50%             0.000000           0.000000                 0.000000
# 75%             0.000000           1.000000                 0.000000
# max             1.000000           1.000000                 1.000000
#
#        Mode_of_Shipment_Road  Mode_of_Shipment_Ship  Product_importance_high  \
# count            6999.000000            6999.000000              6999.000000
# mean                0.153736               0.697671                 0.477925
# std                 0.360722               0.459300                 0.499548
# min                 0.000000               0.000000                 0.000000
# 25%                 0.000000               0.000000                 0.000000
# 50%                 0.000000               1.000000                 0.000000
# 75%                 0.000000               1.000000                 1.000000
# max                 1.000000               1.000000                 1.000000
#
#        Product_importance_low  Product_importance_medium
# count             6999.000000                6999.000000
# mean                 0.082012                   0.440063
# std                  0.274402                   0.496430
# min                  0.000000                   0.000000
# 25%                  0.000000                   0.000000
# 50%                  0.000000                   0.000000
# 75%                  0.000000                   1.000000
# max                  1.000000                   1.000000

# %%
X_test.describe()
# Out:
#        Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count          4000.000000       4000.00000          4000.000000
# mean              3.187250          2.98125           210.420250
# std               1.956053          1.41912            47.755542
# min               0.000000          1.00000            96.000000
# 25%               2.000000          2.00000           170.000000
# 50%               4.000000          3.00000           214.000000
# 75%               5.000000          4.00000           251.000000
# max               7.000000          5.00000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Warehouse_block_A  \
# count      4000.000000       4000.000000    4000.000000        4000.000000
# mean          3.515250         11.710750    3597.761000           0.164750
# std           1.460582         11.548222    1593.715242           0.371001
# min           2.000000          1.000000    1003.000000           0.000000
# 25%           3.000000          7.000000    1876.000000           0.000000
# 50%           3.000000         10.000000    4045.500000           0.000000
# 75%           4.000000         10.000000    4987.500000           0.000000
# max          10.000000         65.000000    7684.000000           1.000000
#
#        Warehouse_block_B  Warehouse_block_C  Warehouse_block_D  \
# count        4000.000000        4000.000000        4000.000000
# mean            0.167750           0.162250           0.166500
# std             0.373691           0.368726           0.372575
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        Warehouse_block_F  Mode_of_Shipment_Flight  Mode_of_Shipment_Road  \
# count        4000.000000              4000.000000            4000.000000
# mean            0.338750                 0.149750               0.154500
# std             0.473344                 0.356871               0.361473
# min             0.000000                 0.000000               0.000000
# 25%             0.000000                 0.000000               0.000000
# 50%             0.000000                 0.000000               0.000000
# 75%             1.000000                 0.000000               0.000000
# max             1.000000                 1.000000               1.000000
#
#        Mode_of_Shipment_Ship  Product_importance_high  Product_importance_low  \
# count            4000.000000              4000.000000             4000.000000
# mean                0.695750                 0.090250                0.468250
# std                 0.460147                 0.286575                0.499053
# min                 0.000000                 0.000000                0.000000
# 25%                 0.000000                 0.000000                0.000000
# 50%                 1.000000                 0.000000                0.000000
# 75%                 1.000000                 0.000000                1.000000
# max                 1.000000                 1.000000                1.000000
#
#        Product_importance_medium
# count                4000.000000
# mean                    0.441500
# std                     0.496628
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     1.000000
# max                     1.000000

# %% [markdown]
# # 테스트 완료됨

# %%
#X_train.to_csv('train_fix_09_12.csv', index=False)
#X_test.to_csv('test_fix_09_12.csv', index=False)

# %%
#11/24
#X_train.to_csv('train_fix_09_12_2.csv', index=False)
#X_test.to_csv('test_fix_09_12_2.csv', index=False)

# %%
#11/35
X_train.to_csv('train_fix_09_12_3.csv', index=False)
X_test.to_csv('test_fix_09_12_3.csv', index=False)

# %%
# 0912_2,3=  레이팅 날림
X_train = X_train.drop('Customer_rating', axis=1) 
X_test = X_test.drop('Customer_rating', axis=1)

# %%
# Product_importance_medium 날림
X_train = X_train.drop('Product_importance_medium', axis=1) 
X_test = X_test.drop('Product_importance_medium', axis=1)

# %%
# Mode_of_Shipment_Road 날림
X_train = X_train.drop('Mode_of_Shipment_Road', axis=1) 
X_test = X_test.drop('Mode_of_Shipment_Road', axis=1)

# %%
# Mode_of_Shipment_Ship 날림
X_train = X_train.drop('Mode_of_Shipment_Ship', axis=1) 
X_test = X_test.drop('Mode_of_Shipment_Ship', axis=1) 
# Mode_of_Shipment_Flight 날림
X_train = X_train.drop('Mode_of_Shipment_Flight', axis=1) 
X_test = X_test.drop('Mode_of_Shipment_Flight', axis=1) 
# Product_importance_high 날림
X_train = X_train.drop('Product_importance_high', axis=1) 
X_test = X_test.drop('Product_importance_high', axis=1) 
# Customer_care_calls 날림
X_train = X_train.drop('Customer_care_calls', axis=1) 
X_test = X_test.drop('Customer_care_calls', axis=1) 
# Prior_purchases 날림
X_train = X_train.drop('Prior_purchases', axis=1) 
X_test = X_test.drop('Prior_purchases', axis=1)

# %%
# Warehouse_block_A 날림
X_train = X_train.drop('Warehouse_block_A', axis=1) 
X_test = X_test.drop('Warehouse_block_A', axis=1)
# Warehouse_block_B 날림
X_train = X_train.drop('Warehouse_block_B', axis=1) 
X_test = X_test.drop('Warehouse_block_B', axis=1)
# Warehouse_block_C 날림
X_train = X_train.drop('Warehouse_block_C', axis=1) 
X_test = X_test.drop('Warehouse_block_C', axis=1)
# Warehouse_block_D 날림
X_train = X_train.drop('Warehouse_block_D', axis=1) 
X_test = X_test.drop('Warehouse_block_D', axis=1)
# Warehouse_block_F 날림
X_train = X_train.drop('Warehouse_block_F', axis=1) 
X_test = X_test.drop('Warehouse_block_F', axis=1)

# %%
# Prior_purchases 날림
