# %% [markdown]
# knn_model    decision tree   -  모두 분류와 회귀 사용가능한 모델 이었음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# T - True(참)
# F - False(거짓)
# N - Nagative(부정)
# P - Positive(긍정)

# %% [markdown]
# 뒤에 있는 알파벳은 예측 값으로 본다
