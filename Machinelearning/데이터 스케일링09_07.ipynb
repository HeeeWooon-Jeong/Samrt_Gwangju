# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 거리가 좁으면 컴퓨터가 데이터 비교하기 편해진다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 스탠다드 스케일러는 -> 회귀 / 분류 를 놓고 봤을때 분류에서 많이 사용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 회귀에 더 유용?? 설명못들음

# %% [markdown]
# ![image.png](attachment:image.png)
