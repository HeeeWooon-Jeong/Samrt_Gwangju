# %% [markdown]
# knn_model    decision tree   -  모두 분류와 회귀 사용가능한 모델 이었음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# T - True(참)
# F - False(거짓)
# N - Nagative(부정)
# P - Positive(긍정)
#
#
#
#
# -------------------------------
#
# 앞에 있는 트루 펄스를 맞췄냐 / 못맞췄냐 로 본다
# 뒤에 있는 값을 예측값 으로 본다
#
# Negative -> False
#
# positive -> True

# %% [markdown]
# 뒤에 있는 알파벳은 예측 값으로 본다

# %% [markdown]
# 성능 평가지표 4가지
#
#
# - 어큐러시 스코어
# 혼동 행렬 - recall
#           - precision
# - F1 - score

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 적중률 이라고도 불림
#
# 애매한 상황에서 True로 보자 할때 사용
# ex) caps

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# 재현율 - 애매한게 예측 되더라도 다 살리는 느낌
# 정밀도 - 애매한건 다 걸러버리는 느낌

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 이진 분류  True 아님 False
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ROC커브 단점 정확한 값을 보여주기 어렵다
#
# 그래프의 면적값을 AUC
#
# AUC 영역이 크면 클수록 좋은 모델이다~~~
#
# ![image.png](attachment:image.png)
