# %% [markdown]
# # 네이버 환율 정보 수집
# - response 응답코드가 200 이여도 데이터가 안넘어 오는 경우 존재
# - 1. iframe에 데이터가 보여질때
# - 2. 데이터 접근이 금지
# - iframe은 개발자 도구에서 검색 후, 실제 주소로 접근(src값을 조회)

# %%
import requests as req
from bs4 import BeautifulSoup as bs

# %%
res = req.get("https://finance.naver.com/marketindex/exchangeList.naver")
res
# Out:
# <Response [200]>

# %%
soup = bs(res.text, "lxml")
soup
# Out:
# <html lang="ko">
# <head>
# <title>네이버 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20230713201205/css/finance.css" rel="stylesheet" type="text/css"/>
# <script language="javascript">document.domain="naver.com";</script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230713201205/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230713201205/js/lcslog.js" type="text/javascript"></script>
# </head>
# <body>
# <div class="tbl_area">
# <table border="1" class="tbl_exchange" summary="환전 고시 환율 리스트">
# <caption>환전 고시 환율</caption>
# <colgroup>
# <col width="162"/>
# <col width="92"/>
# <col width="92"/>
# <col width="92"/>
# <col width="93"/>
# <col width="92"/>
# ...

# %%
soup.select("td.tlt > a")
# Out:
# []

# %% [markdown]
# iframe
# 아이프레임 데이터에 접근하려면 src 주소에 접근하여야 한다.
#
# source = 원본 , 출처
#
# https://finance.naver.com/marketindex/
#
# /exchangeList.naver
#
#
# iframe 형태 태그로 html에 복붙하면 사용할수 있음
# 유튜브 -> 공유 -> 퍼가기

# %%
soup.text
# Out:
# '\n\n네이버 증권\n\n\n\n\n\n\n\n\n\n\n\n환전 고시 환율\n\n\n\n\n\n\n\n\n\n\n\n\n통화명\n매매기준율\n현찰\n송금\n미화환산율\n\n\n사실 때 \n파실 때 \n보내실 때 \n받으실 때\n\n\n\n\n\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t미국 USD\n\t\t\t\t\n\t\t\t\t\n1,265.60\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t1,287.74\n\t\t\t\t\t\n\t\t\t\t\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t1,243.46\n\t\t\t\t\t\n\t\t\t\t\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t1,278.00\n\t\t\t\t\t\n\t\t\t\t\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t1,253.20\n\t\t\t\t\t\n\t\t\t\t\n1.000\n\n\n\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t유럽연합 EUR\n\t\t\t\t\n\t\t\t\t\n1,422.53\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t1,450.83\n\t\t\t\t\t\n\t\t\t\t\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t1,394.23\n\t\t\t\t\t\n\t\t\t\t\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t1,436.75\n\t\t\t\t\t\n\t\t\t\t\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t1,408.31\n\t\t\t\t\t\n\t\t\t\t\n1.124\n\n\n\n\t\t\t\t\n\t\t\t\t\t일본 JPY (100엔)\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t
# ...
