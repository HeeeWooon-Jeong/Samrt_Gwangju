# %% [markdown]
# 시리즈 - 열

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %% [markdown]
# ### Pandas 객체 종류
# - 1차원 Series : index + value
# - 2차원 DataFrame : 표와 같은 형태
# - table 형식의 정형 데이터 를 정리하고 저장하는 자료구조를 지원

# %% [markdown]
# ### Pandas 객체 다루기

# %% [markdown]
# #### 1차원 시리즈 생성

# %%
num_series = pd.Series([3,4,5])
num_series
# 시리즈는 여러 값을 나열한 자료구조
# 시리즈는 index와 value로 구성됨
# 데이터 프레임을 구성하는 하위요소 ==> 시리즈가 여러개 모이면 데이터 프레임을 만듦
# Out:
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
# 인덱스와 값을 가진 시리즈 생성 - 1
num_series2 = pd.Series([3,4,5], index= ['lee', 'kim', 'jang'])
num_series2
# Out:
# lee     3
# kim     4
# jang    5
# dtype: int64

# %%
# 인덱스와 값을 가진 시리즈 생성 - 2
num_series3 = pd.Series({'lee':3, 'kim':4,'jang':5})
num_series3
# Out:
# lee     3
# kim     4
# jang    5
# dtype: int64

# %% [markdown]
# #### 시리즈 속성 확인

# %%
# 값 확인
num_series3.values
# Out:
# array([3, 4, 5], dtype=int64)

# %%
# 인덱스 확인
num_series3.index
# Out:
# Index(['lee', 'kim', 'jang'], dtype='object')

# %%
# 데이터 타입 확인
num_series3.dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### 시리즈와 인덱스에 이름 지정

# %%
print(num_series3.name)
print(num_series3.index.name)
# 이름 지정하기
num_series3.name = 'name_cnt'
num_series3.index.name = 'name'
print(num_series3.name)
print(num_series3.index.name)
# Out:
# None
# None
# name_cnt
# name

# %% [markdown]
# #### 리스트를 이용하여 시리즈 생성하기 - 2020 인구수

# %%
population = pd.Series([9602000, 3344000, 1488000, 2419000], index= ['서울', '부산', '광주', '대구'])
population.index.name = '도시'
population.name = '2020 인구수'
population
# Out:
# 도시
# 서울    9602000
# 부산    3344000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %% [markdown]
# #### 시리즈 데이터의 갱신, 추가 ,삭제

# %%
# 갱신 : 부산 데이터 --> 350000

# %%
population['부산'] = 3500000
population
# Out:
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %%
# 추가 : 대전 - 1500000
population['대전'] = 1500000
population
# Out:
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %%
# 삭제 : del 키워드, drop()
population.drop('서울') # inplace = True로 지정해줘야 삭제된 값이 변수에 반영
population
# Out:
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %%
del population['서울']# 셀이 실행됨과 동시에 변수에 반영

# %%
population
# Out:
# 도시
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %% [markdown]
# #### 2차원 데이터 프레임 생성

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 단일 리스트로 데이터프레임 생성
num = [1, 1, 3]
num_df = pd.DataFrame(num)
num_df
# Out:
#    0
# 0  1
# 1  1
# 2  3

# %%
# 이중리스트로 데이터프레임 생성
num2 = [['big', 1],['ai',1],['iot', 3]]
num2_df= pd.DataFrame(num2)
num2_df
# Out:
#      0  1
# 0  big  1
# 1   ai  1
# 2  iot  3

# %%
# 컬럼 값을 추가 #1 - 데이터 프레임을 생성할 때 같이 
# 인덱스값도 추가하고 싶다면 

num2_df = pd.DataFrame(num2, columns=['Class', 'Join'])
num2_df
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %%
# 딕셔너리 자료를 이용하여 데이터프레임 생성
num3_df = pd.DataFrame({'Class' : ['big', 'ai', 'iot'], 'Join':[1,1,3]})
num3_df
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %% [markdown]
# #### 데이터프레임 속성 확인

# %%
# 값 확인
num3_df.values
# Out:
# array([['big', 1],
#        ['ai', 1],
#        ['iot', 3]], dtype=object)

# %%
# 인덱스 확인
num3_df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# 컬럼명 확인
num3_df.columns
# Out:
# Index(['Class', 'Join'], dtype='object')

# %%
# 데이터 타입 확인
num3_df.dtypes
# Out:
# Class    object
# Join      int64
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
person_inf = [[175.3, 180.2, 178.6],[66.2, 78.9, 55.1],[27.0, 49.0, 45.0]]
person_inf
# Out:
# [[175.3, 180.2, 178.6], [66.2, 78.9, 55.1], [27.0, 49.0, 45.0]]

# %%
person_info = pd.DataFrame(person_inf)
person_info
# Out:
#        0      1      2
# 0  175.3  180.2  178.6
# 1   66.2   78.9   55.1
# 2   27.0   49.0   45.0

# %%
person_info = pd.DataFrame(person_inf, columns=['키', '몸무게', '나이'])
person_info
# Out:
#        키    몸무게     나이
# 0  175.3  180.2  178.6
# 1   66.2   78.9   55.1
# 2   27.0   49.0   45.0

# %% [markdown]
# #### 예제

# %%
# 판다스에 있는 데이터프레임 객체를 만들겠다
person_info = pd.DataFrame({'키' : [175.3, 180.2, 178.6],
                           '몸무게' :[66.2, 78.9, 55.1],
                           '나이' : [27.0, 49.0, 45.0]},
                          index = ['son', 'kim', 'park'])
person_info
# Out:
#           키   몸무게    나이
# son   175.3  66.2  27.0
# kim   180.2  78.9  49.0
# park  178.6  55.1  45.0

# %%
# 행렬 전환 : .T     행렬 인덱스 전환
person_info.T
# Out:
#        son    kim   park
# 키    175.3  180.2  178.6
# 몸무게   66.2   78.9   55.1
# 나이    27.0   49.0   45.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
person_info.values
# Out:
# array([[175.3,  66.2,  27. ],
#        [180.2,  78.9,  49. ],
#        [178.6,  55.1,  45. ]])

# %%
person_info.dtypes
# Out:
# 키      float64
# 몸무게    float64
# 나이     float64
# dtype: object

# %%
person_info.index
# Out:
# Index(['son', 'kim', 'park'], dtype='object')

# %%
person_info.columns
# Out:
# Index(['키', '몸무게', '나이'], dtype='object')

# %% [markdown]
# ### Pandas 데이터 접근

# %%
num_series3
# Out:
# name
# lee     3
# kim     4
# jang    5
# Name: name_cnt, dtype: int64

# %%
# 인덱스 번호로 접근 

print(num_series3[0])
print(num_series3[1])
print(num_series3[2])
# Out:
# 3
# 4
# 5

# %%
# 인덱스 라벨로 접근
print(num_series3['lee'])
print(num_series3['kim'])
print(num_series3['jang'])
# Out:
# 3
# 4
# 5

# %%
# 여러개 접근
display(num_series3[['lee', 'kim']])
display(num_series3[[0, 1]])
# Out:
# name
# lee    3
# kim    4
# Name: name_cnt, dtype: int64
# name
# lee    3
# kim    4
# Name: name_cnt, dtype: int64

# %%
# 여러개 접근
# 인덱싱
display(num_series3[['jang','kim']])
display(num_series3[[2,1]])
# 슬라이싱
display(num_series3[:2])
display(num_series3['kim':'jang']) # 문자열로 접근할 때 끝값이 포함됨
# Out:
# name
# jang    5
# kim     4
# Name: name_cnt, dtype: int64
# name
# jang    5
# kim     4
# Name: name_cnt, dtype: int64
# name
# lee    3
# kim    4
# Name: name_cnt, dtype: int64
# name
# kim     4
# jang    5
# Name: name_cnt, dtype: int64

# %% [markdown]
# #### 데이터 프레임 열 접근

# %%
num3_df
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %%
num3_df[['Class','Join']]
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %% [markdown]
# #### 데이터 프레임 행 데이터 접근

# %%
num4_df=num3_df.set_index('Class')
num4_df
# Out:
#        Join
# Class
# big       1
# ai        1
# iot       3

# %%
num3_df
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %%
# 슬라이싱으로 행에 접근
num4_df[1:]
# Out:
#        Join
# Class
# ai        1
# iot       3

# %%
num4_df[:'ai']
# Out:
#        Join
# Class
# big       1
# ai        1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 데이터 프레임 행, 열 데이터에 더 편리하게 접근하기
# - loc, iloc 인덱서
# - loc : 실제로 보이는 라벨명을 통해 데이터에 접근하는 방법
# - iloc : 넘파이 배열 인덱스값을 통해 데이터에 접근하는 방법
#     i : integer이 index 번호값의 loc(위치)에 접근함
# - 데이터.인덱서[행, 열]
#     - 콤마(,)앞은 행, 콤마(,) 뒤는 열의 값을 입ㅂ력
#     - 행, 열 자리 모두 여러개에 접근할 경우 [요소1, 요소2 ...]
#     - 슬라이싱 [ : ]을 통해서 접근

# %%
num4_df
# Out:
#        Join
# Class
# big       1
# ai        1
# iot       3

# %%
# iot 행 데이터 접근하기
# 인덱스 번호
display(num4_df.iloc[2])
# 인덱스 라벨
display(num4_df.loc['iot'])
# Out:
# Join    3
# Name: iot, dtype: int64
# Join    3
# Name: iot, dtype: int64

# %%
# big행, ai행 데이터 행 접근
# 인덱스 번호
display(num4_df.iloc[:2])
# 인덱스 라벨
display(num4_df.loc[:'ai'])
# Out:
#        Join
# Class
# big       1
# ai        1
#        Join
# Class
# big       1
# ai        1

# %%
# join 열에 접근하기
# 데이터.인덱서[행,열]
# 인덱스 번호
display(num4_df.iloc[:, 0])

# 인덱스 라벨
display(num4_df.loc[:,'Join'])
# Out:
# Class
# big    1
# ai     1
# iot    3
# Name: Join, dtype: int64
# Class
# big    1
# ai     1
# iot    3
# Name: Join, dtype: int64

# %%
num4_df
# Out:
#        Join
# Class
# big       1
# ai        1
# iot       3

# %%
display(num4_df.iloc[0, 0])
# Out:
# 1

# %%
#big의 join 데이터 접근하기
display(num4_df.iloc[:1,0])
# Out:
# Class
# big    1
# Name: Join, dtype: int64

# %%
person_info
# Out:
#           키   몸무게    나이
# son   175.3  66.2  27.0
# kim   180.2  78.9  49.0
# park  178.6  55.1  45.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
person_info.iloc[0,2]
# Out:
# 27.0

# %%
# son의 나이 데이터 접근
person_info.loc['son', '나이']
# Out:
# 27.0

# %%
# son의 키, 나이데이터 접근하기
person_info.loc['son',['키', '나이']]
# Out:
# 키     175.3
# 나이     27.0
# Name: son, dtype: float64

# %%
# kim과 park의 몸무게, 키를 순서대로 접근하기
person_info.loc['kim' : 'park', ['몸무게', '키']]
# Out:
#        몸무게      키
# kim   78.9  180.2
# park  55.1  178.6

# %%
person_info.iloc[1:, [1, 0]]
person_info.iloc[[1, 2], [1,0]]
# Out:
#        몸무게      키
# kim   78.9  180.2
# park  55.1  178.6

# %%
display(person_info.iloc[0,[0, 2]])
# Out:
# 키     175.3
# 나이     27.0
# Name: son, dtype: float64

# %%
display(person_info.iloc[1,[2, 1]])
display(person_info.iloc[2,[2, 1]])
# Out:
# 나이     49.0
# 몸무게    78.9
# Name: kim, dtype: float64
# 나이     45.0
# 몸무게    55.1
# Name: park, dtype: float64

# %% [markdown]
# #### 조건에 맞는 데이터 접근하기 : 불리언 인덱싱

# %%
num3_df
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %%
# join 값이 2 이상인 데이터 접근하기
num3_df[num3_df['Join'] >= 2]
# Out:
#   Class  Join
# 2   iot     3

# %%
# 문자값으로 조건 : class가 big이거나 ai인 데이터 추출 ==> or, |
num3_df[(num3_df['Class'] == 'big') | (num3_df['Class'] == 'ai')]
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1

# %%
# Join 값이 2 이하인 Class 이름을 리스트나 배열로 출력하기
Cl= []
Cl=num3_df[num3_df['Join'] <=2]['Class']
display(Cl)
# Out:
# 0    big
# 1     ai
# Name: Class, dtype: object

# %%
num3_df['Join'] <=2
# Out:
# 0     True
# 1     True
# 2    False
# Name: Join, dtype: bool

# %%
num3_df[num3_df['Join'] <=2]['Class'].values
# Out:
# array(['big', 'ai'], dtype=object)

# %%
num3_df.loc[num3_df['Join'] <=2, 'Class'].values
# Out:
# array(['big', 'ai'], dtype=object)

# %% [markdown]
# #### query() 함수를 통한 행 접근
# - 판다스의 query함수는 SQL의 where 함수의 역할
# - query함수의 장점
#     - 분석 코드가 간결
#     - 가독성이 좋음
#     - 조건 결합을 사용하는 경우 더욱 강력해짐.

# %%
num3_df.query('Join <= 2')
# num3_df[num3_df['Join'] <=2 와 같음
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1

# %%
# 문자값 : Class가 ai이거나 iot인 데이터 추출
# 전체 조건과 추출할 문자의 따옴표 구별하기
num3_df.query('Class == "ai" | Class == "iot"')
# Out:
#   Class  Join
# 1    ai     1
# 2   iot     3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num3_df.query('Join <= 2')['Class'].size
# Out:
# 2

# %%
num3_df.loc[num3_df['Join']<=2,'Class'].size
# Out:
# 2

# %% [markdown]
# ### 판다스 연산 및 유용한 함수
#
# #### 파일 불러오기 및 저장

# %%
exam = pd.read_csv('./data/exam.csv')
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 데이터 파악하기
# - head() : 앞에서 5개 행 출력
# - tail() : 뒤에서 5개 행 출력
# - shape : 행 , 열 개수 출력
# - info() : 변수 속성 출력
# - describe() : 요약 통계량 출력

# %%
exam.head(3)   # 기본값은 5개지만 매개변수로 int값을 넣으면 된다
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78

# %%
exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.shape
# Out:
# (20, 5)

# %%
exam.info() # 데이터의 요약정보
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
exam.info()
# 컬럼들의 속성을 보여주는 함수
# 모든 컬럼들의 속성을 한 눈에 파악할 수 있음
# 1. <class 'pandas.core.frame.DataFrame'> 
# ==> 판다스의 데이터 프레임 객체
# 2. RangeIndex: 20 entries, 0 to 19
# 3. Data columns (total 5 columns) ==> 컬럼(변수)개수 총 5개 구성
# 4. # ==> 변수 순서(인덱스 개념)
# 5. Column ==> 커럼명
# 6. Non-Null Count ==> 컬럼(변수)에 들어있는 값의 개수
#                       결측치를 제외하고 구한 값의 개수를 나타냄
# 7. Dtype ==> 데이터 타입
#    int64 ==> 변수가 64비트로 되어있다는 의미
#    1비트로 두개의 값을 표현할 수 있으므로 int64는 2^64개의 정수를 표현할 수 있다는 의미
#    int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
exam.describe(include=all)
# 모든 변수의 요약 통계량 ==> 기본적으로 숫자값들에 대한 통계정보 표시
#                             문자로 된 변수의 요약 통계량을 함께 출력하려면?
#                             decribe(include = 'all')로 설정 
# 1. count ==> 빈도(frequency). 값의 개수
# 2. mean  ==> 평균, 모든 값을 더해 값의 개수로 나눈 값
# 3. std ==> 변수 값들의 평균에서 떨어진 정도를 나타내는 값
# 4. min ==> 최소값, 가장 작은 값
# 5. 25% ==> 1사 분위수
# 6. 50% ==> 중위수(중앙값)
# 7. 75% ==> 3사 분위수
# 8. max ==> 최대값, 가장 큰 값
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# #### 데이터 정렬
# - sort_values()

# %%
# 1차원 데이터의 정렬
exam['math'].sort_values() #오름차순 정렬이 기본값
#ascending=True 오름차순
# Out:
# 8     20
# 4     25
# 3     30
# 2     45
# 11    45
# 12    46
# 13    48
# 0     50
# 9     50
# 5     50
# 15    58
# 1     60
# 10    65
# 16    65
# 14    75
# 19    78
# 6     80
# 17    80
# 18    89
# 7     90
# Name: math, dtype: int64

# %%
# 수학성적을 내림차순으로 정렬하기
exam['math'].sort_values(ascending=False)
# Out:
# 7     90
# 18    89
# 17    80
# 6     80
# 19    78
# 14    75
# 16    65
# 10    65
# 1     60
# 15    58
# 9     50
# 5     50
# 0     50
# 13    48
# 12    46
# 11    45
# 2     45
# 3     30
# 4     25
# 8     20
# Name: math, dtype: int64

# %%
# 2차원 데이터의 정렬
# 1. 수학컬럼을 정렬하여 top 5 학생 확인
# 2. 학생 id를 기준으로 출력

# %%
exam[['id','math']].sort_values(by='math', ascending=False).head()
# Out:
#     id  math
# 7    8    90
# 18  19    89
# 17  18    80
# 6    7    80
# 19  20    78

# %%
# 수학컬럼을 정렬하여 뒤에서 3명 확인
exam[['id','math']].sort_values(by='math', ascending=False).tail(3)
# Out:
#    id  math
# 3   4    30
# 4   5    25
# 8   9    20

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. mpg = 
mpg = pd.read_csv('./data/mpg.csv')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
# 2. 앞, 뒤 3개씩 출력하기
display(mpg.head(3))
display(mpg.tail(3))
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 231  midsize
# 232  midsize
# 233  midsize

# %%
# 3. 데이터 크기(행, 열) 확인
mpg.shape
# Out:
# (234, 11)

# %%
# 4. 데이터 속성 확인
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
# 5. 요약 통계량 확인
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg[mpg['manufacturer']== 'audi']['hwy'].sort_values(ascending=False)
# Out:
# 2     31
# 3     30
# 0     29
# 1     29
# 9     28
# 6     27
# 10    27
# 5     26
# 7     26
# 4     26
# 8     25
# 11    25
# 12    25
# 13    25
# 14    25
# 16    25
# 15    24
# 17    23
# Name: hwy, dtype: int64

# %%
# 6. 'audi' 에서 생산한 자동차중 고속도로 연비 top 5 출력
mpg[mpg['manufacturer']== 'audi'].sort_values(by='hwy',ascending=False).head()
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#   category
# 2  compact
# 3  compact
# 0  compact
# 1  compact
# 9  compact
