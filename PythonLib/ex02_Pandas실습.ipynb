# %% [markdown]
# ### Pandas 사용하기

# %%
import pandas as pd

# %% [markdown]
# ### Pandas 객체 종류
# - 1차원 Series : index + value
# - 2차원 DataFrame : 표와 같은 형태
# - table 형식의 정형 데이터를 정리하고 저장하는 자료구조를 지원

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Pandas 객체 다루기

# %% [markdown]
# #### 1차원 시리즈 생성

# %%
num_series = pd.Series([3, 4, 5])
num_series
# 시리즈는 여러 값을 나열한 자료구조
# 시리즈는 index와 value로 구성됨
# 데이터 프레임을 구성하는 하위요소 ==> 시리즈가 여러개 모이면 데이터 프레임을 만듦
# Out:
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
# 인덱스와 값을 가진 시리즈 생성 - 1
num_series2 = pd.Series([3, 4, 5], index= ['lee', 'kim', 'jang'])
num_series2
# Out:
# lee     3
# kim     4
# jang    5
# dtype: int64

# %%
# 인덱스와 값을 가진 시리즈 생성 - 2
num_series3 = pd.Series({'lee' : 3, 'kim' : 4, 'jang' : 5})
num_series3
# Out:
# lee     3
# kim     4
# jang    5
# dtype: int64

# %% [markdown]
# #### 시리즈 속성 확인

# %%
# 값 확인
num_series3.values
# Out:
# array([3, 4, 5], dtype=int64)

# %%
# 인덱스 확인
num_series3.index
# Out:
# Index(['lee', 'kim', 'jang'], dtype='object')

# %%
# 데이터 타입 확인
num_series3.dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### 시리즈와 인덱스에 이름 지정

# %%
print(num_series3.name)
print(num_series3.index.name)
# 이름 지정하기
num_series3.name = 'name_cnt'
num_series3.index.name = 'name'
print(num_series3.name)
print(num_series3.index.name)
# Out:
# None
# None
# name_cnt
# name

# %% [markdown]
# #### 리스트를 이용하여 시리즈 생성하기 - 2020 인구수

# %%
population = pd.Series([9602000, 3344000, 1488000, 2419000], 
                       index = ['서울', '부산', '광주', '대구'])
population.index.name = '도시'
population.name = '2020 인구수'
population
# Out:
# 도시
# 서울    9602000
# 부산    3344000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %% [markdown]
# #### 시리즈 데이터의 갱신, 추가, 삭제

# %%
# 갱신 : 부산 데이터 --> 3500000
population['부산'] = 3500000
population
# Out:
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %%
# 추가 : 대전 - 1500000
population['대전'] = 1500000
population
# Out:
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %%
# 삭제 : del 키워드, drop()
population.drop('서울')  # inplace = True 로 지정해줘야 삭제된 값이 변수에 반영
# Out:
# 도시
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %%
population
# Out:
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %%
del population['서울']  # 셀이 실행됨과 동시에 변수에 반영

# %%
population
# Out:
# 도시
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %% [markdown]
# #### 2차원 데이터프레임 생성

# %%
# 단일 리스트로 데이터프레임 생성
num = [1, 1, 3]
num_df = pd.DataFrame(num)
num_df
# Out:
#    0
# 0  1
# 1  1
# 2  3

# %%
# 이중리스트로 데이터프레임 생성
num2 = [['big', 1], ['ai', 1], ['iot', 3]]
num2_df = pd.DataFrame(num2)
num2_df
# Out:
#      0  1
# 0  big  1
# 1   ai  1
# 2  iot  3

# %%
# 컬럼 값을 추가 #1 - 데이터 프레임을 생성할 때 같이
# 인덱스값도 추가하고 싶다면 
num2_df = pd.DataFrame(num2, columns=['Class', 'Join'], index =['c1', 'c2', 'c3'])
num2_df
# Out:
#    Class  Join
# c1   big     1
# c2    ai     1
# c3   iot     3

# %%
# 딕셔너리 자료를 이용하여 데이터프레임 생성
num3_df = pd.DataFrame({'Class' : ['big', 'ai', 'iot'], 'Join' : [1, 1, 3]})
num3_df
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %% [markdown]
# #### 데이터프레임 속성 확인

# %%
# 값 확인
num3_df.values
# Out:
# array([['big', 1],
#        ['ai', 1],
#        ['iot', 3]], dtype=object)

# %%
# 인덱스 확인
num3_df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# 컬럼명 확인
num3_df.columns
# Out:
# Index(['Class', 'Join'], dtype='object')

# %%
# 데이터 타입 확인
num3_df.dtypes
# Out:
# Class    object
# Join      int64
# dtype: object

# %% [markdown]
# #### 예제
# ![image.png](attachment:image.png)

# %%
person_info = pd.DataFrame({'키' : [175.3, 180.2, 178.6], 
                           '몸무게' : [66.2, 78.9, 55.1],
                           '나이' : [27.0, 49.0, 35.0]},
                          index = ['son', 'kim', 'park'])
person_info
# Out:
#           키   몸무게    나이
# son   175.3  66.2  27.0
# kim   180.2  78.9  49.0
# park  178.6  55.1  35.0

# %%
# 행렬 전환 : .T
person_info.T
# Out:
#        son    kim   park
# 키    175.3  180.2  178.6
# 몸무게   66.2   78.9   55.1
# 나이    27.0   49.0   35.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. 밸류(값) 확인
person_info.values
# Out:
# array([[175.3,  66.2,  27. ],
#        [180.2,  78.9,  49. ],
#        [178.6,  55.1,  35. ]])

# %%
# 2. 데이터 타입 확인
person_info.dtypes
# Out:
# 키      float64
# 몸무게    float64
# 나이     float64
# dtype: object

# %%
# 3. 인덱스 값 확인
person_info.index
# Out:
# Index(['son', 'kim', 'park'], dtype='object')

# %%
# 4. 컬럼명 확인
person_info.columns
# Out:
# Index(['키', '몸무게', '나이'], dtype='object')

# %% [markdown]
# ### Pandas 데이터 접근

# %% [markdown]
# #### 시리즈 데이터 접근

# %%
num_series3
# Out:
# name
# lee     3
# kim     4
# jang    5
# Name: name_cnt, dtype: int64

# %%
# 인덱스 번호로 접근
print(num_series3[0])
print(num_series3[1])
print(num_series3[2])
# Out:
# 3
# 4
# 5

# %%
# 인덱스 라벨로 접근
print(num_series3['lee'])
print(num_series3['kim'])
print(num_series3['jang'])
# Out:
# 3
# 4
# 5

# %%
# 여러개 접근 
# 인덱싱
display(num_series3[['jang', 'kim']])
display(num_series3[[2, 1]])
# 슬라이싱
display(num_series3[:2])
display(num_series3[:'jang'])  # 문자열로 접근할 때 끝값이 포함됨
# Out:
# name
# jang    5
# kim     4
# Name: name_cnt, dtype: int64
# name
# jang    5
# kim     4
# Name: name_cnt, dtype: int64
# name
# lee    3
# kim    4
# Name: name_cnt, dtype: int64
# name
# lee     3
# kim     4
# jang    5
# Name: name_cnt, dtype: int64

# %% [markdown]
# #### 데이터 프레임 열 데이터 접근

# %%
num3_df
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %%
num3_df['Class']
# Out:
# 0    big
# 1     ai
# 2    iot
# Name: Class, dtype: object

# %%
num3_df[['Class']]
# Out:
#   Class
# 0   big
# 1    ai
# 2   iot

# %%
# 여러 컬럼을 한꺼번에 접근(추출)하기
num3_df[['Class', 'Join']]
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %% [markdown]
# #### 데이터 프레임 행 데이터 접근

# %%
num4_df = num3_df.set_index('Class')
num4_df
# Out:
#        Join
# Class
# big       1
# ai        1
# iot       3

# %%
# 슬라이싱으로 행에 접근
num4_df[1:]
# Out:
#        Join
# Class
# ai        1
# iot       3

# %%
num4_df[:1]
# Out:
#        Join
# Class
# big       1

# %%
num4_df['big':'ai']
# Out:
#        Join
# Class
# big       1
# ai        1

# %% [markdown]
# #### 데이터 프레임 행, 열 데이터에 더 편리하게 접근하기
# - loc, iloc 인덱서
# - loc : 실제로 보이는 라벨명을 통해 데이터에 접근하는 방법
# - iloc : 넘파이 배열 인덱스값을 통해 데이터에 접근하는 방법
#          i : integer이 index 번호값의 loc(위치)에 접근함.
# - 데이터.인덱서[행, 열]
#     - 콤마(,)앞은 행, 콤마(,) 뒤는 열의 값을 입력
#     - 행, 열 자리 모두 여러개에 접근할 경우 [요소1, 요소2, ....]
#     - 슬라이싱[ : ]을 통해서 접근

# %%
num4_df
# Out:
#        Join
# Class
# big       1
# ai        1
# iot       3

# %%
# iot 행 데이터 접근하기
# 인덱스 번호
display(num4_df.iloc[2])
# 인덱스 라벨
display(num4_df.loc['iot'])
# Out:
# Join    3
# Name: iot, dtype: int64
# Join    3
# Name: iot, dtype: int64

# %%
# big, ai 데이터 행 접근
# 인덱스 번호
display(num4_df.iloc[:2])
# 인덱스 라벨
display(num4_df.loc[:'ai'])
# Out:
#        Join
# Class
# big       1
# ai        1
#        Join
# Class
# big       1
# ai        1

# %%
# Join 열에 접근하기
# 데이터.인덱서[행, 열]
# 인덱스 번호
display(num4_df.iloc[:, 0])
# 인덱스 라벨
display(num4_df.loc[:, 'Join'])
# Out:
# Class
# big    1
# ai     1
# iot    3
# Name: Join, dtype: int64
# Class
# big    1
# ai     1
# iot    3
# Name: Join, dtype: int64

# %%
# big의 join 데이터 접근하기
display(num4_df.iloc[0, 0])  # 인덱스 번호
display(num4_df.loc['big', 'Join']) # 인덱스 라벨
# Out:
# 1
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. son의 나이데이터 접근하기
person_info.loc['son', '나이']
# Out:
# 27.0

# %%
# 2. son의 키, 나이데이터 접근하기
person_info.loc['son', ['키', '나이']]
# Out:
# 키     175.3
# 나이     27.0
# Name: son, dtype: float64

# %%
# 3. kim과 park의 몸무게, 키를 순서대로 접근하기
person_info.loc['kim':'park', ['몸무게', '키']]
# Out:
#        몸무게      키
# kim   78.9  180.2
# park  55.1  178.6

# %%
person_info.iloc[1:, [1, 0]]
# Out:
#        몸무게      키
# kim   78.9  180.2
# park  55.1  178.6

# %%
person_info.iloc[[1, 2], [1, 0]]
# Out:
#        몸무게      키
# kim   78.9  180.2
# park  55.1  178.6

# %% [markdown]
# #### 조건에 맞는 데이터 접근하기 : 불리언 인덱싱

# %%
num3_df
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1
# 2   iot     3

# %%
num3_df['Join'] >= 2
# Out:
# 0    False
# 1    False
# 2     True
# Name: Join, dtype: bool

# %%
# Join 값이 2 이상인 데이터 접근하기
num3_df[num3_df['Join'] >= 2]
# Out:
#   Class  Join
# 2   iot     3

# %%
# 문자값으로 조건 : class가 big이거나 ai인 데이터 추출 ==> or, |
num3_df[(num3_df['Class'] =='big') | (num3_df['Class'] =='ai')]
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1

# %%
# Join값이 2이하인 Class 이름을 리스트나 배열로 출력하기
num3_df[num3_df['Join'] <= 2]['Class'].values
# Out:
# array(['big', 'ai'], dtype=object)

# %%
num3_df.loc[num3_df['Join'] <= 2, 'Class'].values
# Out:
# array(['big', 'ai'], dtype=object)

# %% [markdown]
# #### query() 함수를 통한 행 접근
# - 판다스의 query함수는 SQL의 where 함수의 역할
# - query함수의 장점
#     - 분석 코드가 간결
#     - 읽기도 더 쉬움
#     - 조건 결합을 사용하는 경우 더욱 강력해짐.

# %%
num3_df.query('Join <= 2')  # num3_df[num3_df['Join'] <= 2]
# Out:
#   Class  Join
# 0   big     1
# 1    ai     1

# %%
# 문자값 : Class가 ai이거나 iot인 데이터 추출
# 전체 조건과 추출할 문자의 따옴표 구별하기 ==> 중요
num3_df.query(' Class == "ai" | Class == "iot" ')
# Out:
#   Class  Join
# 1    ai     1
# 2   iot     3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num3_df.query('Join <= 2')['Class'].size
# Out:
# 2

# %%
num3_df.loc[num3_df['Join'] <= 2, 'Class'].size
# Out:
# 2

# %% [markdown]
# ### 판다스 연산 및 유용한 함수

# %% [markdown]
# #### 파일 불러오기 및 저장

# %%
exam = pd.read_csv('./data/exam.csv')
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# #### 데이터 파악하기
# - head() : 앞에서 5개 행 출력
# - tail() : 뒤에서 5개 행 출력
# - shape : 행, 열 개수 출력
# - info() : 변수 속성 출력
# - describe() : 요약 통계량 출력

# %%
exam.head(3)  # 기본값 = 5
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78

# %%
exam.tail(2)  # 기본값 = 5
# Out:
#     id  nclass  math  english  science
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.shape
# Out:
# (20, 5)

# %%
exam.info()
# 컬럼들의 속성을 보여주는 함수
# 모든 컬럼들의 속성을 한 눈에 파악할 수 있음
# 1. <class 'pandas.core.frame.DataFrame'> ==> 판다스의 데이터 프레임 객체
# 2. RangeIndex: 20 entries, 0 to 19 ==> 0 ~ 19번 인덱스로 총 20개의 행 구성
# 3. Data columns (total 5 columns) ==> 컬럼(변수)개수 총 5개 구성
# 4. # ==> 변수 순서(인덱스 개념)
# 5. Column ==> 컬럼명
# 6. Non-Null Count ==> 컬럼(변수)에 들어있는 값의 개수
#                       결측치를 제외하고 구한 값의 개수를 나타냄
# 7. Dtype ==> 데이터 타입
#    int64 ==> 변수가 64비트로 되어있다는 의미
#    1비트로 두개의 값(0, 1)을 표현할 수 있으므로 
#    int64는 2^64개의 정수를 표현할 수 있다는 의미
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
exam.describe()
# 모든 변수의 요약 통계량 ==> 기본적으로 숫자값들에 대한 통계정보 표시
#                             문자로 된 변수의 요약 통계량을 함께 출력하려면?
#                             describe(include = 'all')로 설정 

# 1. count ==> 빈도(frequency), 값의 개수
# 2. mean ==> 평균, 모든 값을 더해 값의 개수로 나눈 값
# 3. std ==> 표준편차, 변수 값들이 평균에서 떨어진 정도를 나타내는 값
# 4. min ==> 최소값, 가장 작은 값
# 5. 25% ==> 1사분위수
# 6. 50% ==> 중위수(중앙값)
# 7. 75% ==> 3사분위수 
# 8. max ==> 최대값, 가장 큰 값
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# #### 데이터 정렬
# - sort_values()

# %%
# 1차원 데이터의 정렬
exam['math'].sort_values() # 기본값 : ascending=True 오름차순
# Out:
# 8     20
# 4     25
# 3     30
# 2     45
# 11    45
# 12    46
# 13    48
# 0     50
# 9     50
# 5     50
# 15    58
# 1     60
# 10    65
# 16    65
# 14    75
# 19    78
# 6     80
# 17    80
# 18    89
# 7     90
# Name: math, dtype: int64

# %%
# 수학성적을 내림차순으로 정렬하기
exam['math'].sort_values(ascending=False)
# Out:
# 7     90
# 18    89
# 17    80
# 6     80
# 19    78
# 14    75
# 16    65
# 10    65
# 1     60
# 15    58
# 9     50
# 5     50
# 0     50
# 13    48
# 12    46
# 11    45
# 2     45
# 3     30
# 4     25
# 8     20
# Name: math, dtype: int64

# %%
# 2차원 데이터의 정렬
# 1. 수학컬럼을 정렬하여 top 5 학생 확인
# 2. 학생id 와 수학성적을 출력
exam[['id', 'math']].sort_values(by='math', ascending=False).head()
# Out:
#     id  math
# 7    8    90
# 18  19    89
# 17  18    80
# 6    7    80
# 19  20    78

# %%
# 수학컬럼을 정렬하여 뒤에서 3명 확인
exam[['id', 'math']].sort_values(by='math', ascending=False).tail(3)
# Out:
#    id  math
# 3   4    30
# 4   5    25
# 8   9    20

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. 
mpg = pd.read_csv('./data/mpg.csv')

# %%
# 2. 앞, 뒤 3개씩 출력하기

# %%
# 3. 데이터 크기(행, 열) 확인

# %%
# 4. 데이터 속성 확인

# %%
# 5. 요약 통계량 확인
mpg.describe(include='all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# unique        10    3         NaN         NaN    5        7
# top     auto(l4)    f         NaN         NaN    r      suv
# freq          83  106         NaN         NaN  168       62
# mean         NaN  NaN   16.858974   23.440171  NaN      NaN
# std          NaN  NaN    4.255946    5.954643  NaN      NaN
# min          NaN  NaN    9.000000   12.000000  NaN      NaN
# 25%          NaN  NaN   14.000000   18.000000  NaN      NaN
# 50%          NaN  NaN   17.000000   24.000000  NaN      NaN
# 75%          NaN  NaN   19.000000   27.000000  NaN      NaN
# max          NaN  NaN   35.000000   44.000000  NaN      NaN

# %%
# 6. 'audi'에서 생산한 자동차중 고속도로 연비 top5 출력
audi_data = mpg.query('manufacturer == "audi"')
audi_data.sort_values(by='hwy', ascending=False).head()
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#   category
# 2  compact
# 3  compact
# 0  compact
# 1  compact
# 9  compact

# %% [markdown]
# #### 파생변수(컬럼) 추가
# - 파생변수(derived variable) ? 기존의 변수를 변형해서 만든 변수
# - 데이터에 들어있는 변수만 이용해서 분석할 수도 있지만,
#   변수를 조합하거나 함수를 이용해서 새 변수를 만들어 분석에 가능
# - 컬럼을 추가하는 방법
#     - 방법 1 : 데이터['새컬럼명'] = 데이터 만드는 공식
#     - 방법 2 : 데이터.assign(새컬럼명 = 데이터 만드는 공식)
#         - assign() : 변수 추가, 내부 새로운 컬럼명 지정할 때 사용, 따옴표 X
#         - 여러개의 컬럼을 동시에 추가 생성 가능

# %%
exam.head(3)
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78

# %%
# 방법 1 : 데이터['새컬럼명'] = 데이터 만드는 공식

# sum() 이용
# 학생들의 수학, 영어, 과학점수를 더해 'total' 컬럼을 생성
exam['total'] = exam[['math', 'english', 'science']].sum(axis=1) # 열의 방향 
exam
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# 19  20       5    78       83       58    219

# %%
# 방법 2 : 데이터.assign(새컬럼명 = 데이터 만드는 공식)

# 'total' 컬럼을 이용해서 'mean' 컬럼을 생성
exam = exam.assign(mean = exam['total'] / 3)

# %%
exam
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# 15  16       4    58       98       65    221  73.666667
# 16  17       5    65       68       98    231  77.000000
# 17  18       5    80       78       90    248  82.666667
# 18  19       5    89       68       87    244  81.333333
# 19  20       5    78       83       58    219  73.000000

# %%
# lambda 함수를 이용해서 새로운 컬럼 생성
# 수학, 영어, 과학 점수를 이용해 'mean2' 컬럼 생성

# exam ==> lambda x
exam.assign(mean2 = lambda x : (x['math'] + x['english'] + x['science']) / 3)

# lambda 함수의 장점 
# x : 데이터프레임명
# 데이터프레임명 자리에 x를 입력하겠다는 의미로 코드가 간결
# Out:
#     id  nclass  math  english  science  total       mean      mean2
# 0    1       1    50       98       50    198  66.000000  66.000000
# 1    2       1    60       97       60    217  72.333333  72.333333
# 2    3       1    45       86       78    209  69.666667  69.666667
# 3    4       1    30       98       58    186  62.000000  62.000000
# 4    5       2    25       80       65    170  56.666667  56.666667
# 5    6       2    50       89       98    237  79.000000  79.000000
# 6    7       2    80       90       45    215  71.666667  71.666667
# 7    8       2    90       78       25    193  64.333333  64.333333
# 8    9       3    20       98       15    133  44.333333  44.333333
# 9   10       3    50       98       45    193  64.333333  64.333333
# 10  11       3    65       65       65    195  65.000000  65.000000
# 11  12       3    45       85       32    162  54.000000  54.000000
# 12  13       4    46       98       65    209  69.666667  69.666667
# 13  14       4    48       87       12    147  49.000000  49.000000
# 14  15       4    75       56       78    209  69.666667  69.666667
# 15  16       4    58       98       65    221  73.666667  73.666667
# 16  17       5    65       68       98    231  77.000000  77.000000
# 17  18       5    80       78       90    248  82.666667  82.666667
# 18  19       5    89       68       87    244  81.333333  81.333333
# 19  20       5    78       83       58    219  73.000000  73.000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
# 조건에 따라 다른 값을 부여하여 데이터를 생성후 파생변수(컬럼) 추가
# np.where() ==> (조건, 참, 거짓) : mean>= 60, pass, fail

# 평균값이 60점이상이면 pass, 미만이면 fail
exam = exam.assign(result = np.where(exam['mean'] >= 60, 'pass', 'fail'))
exam.head(10)
# Out:
#    id  nclass  math  english  science  total       mean result
# 0   1       1    50       98       50    198  66.000000   pass
# 1   2       1    60       97       60    217  72.333333   pass
# 2   3       1    45       86       78    209  69.666667   pass
# 3   4       1    30       98       58    186  62.000000   pass
# 4   5       2    25       80       65    170  56.666667   fail
# 5   6       2    50       89       98    237  79.000000   pass
# 6   7       2    80       90       45    215  71.666667   pass
# 7   8       2    90       78       25    193  64.333333   pass
# 8   9       3    20       98       15    133  44.333333   fail
# 9  10       3    50       98       45    193  64.333333   pass

# %% [markdown]
# #### 복잡한 기능 연결하는 함수 : apply()

# %%
# exam 데이터를 새로 불러와서 exam2 변수에 담아주기
exam2 = pd.read_csv('./data/exam.csv')
exam2
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# 1. 3과목의 평균을 구해서
# 2. 85점 이상 : A
#    70점 이상 : B
#    60점 이상 : C
#    나머지 : F 

# 함수정의
# 행 하나(한 학생의 성적 데이터)를 받아서 평균을 구하고 학점 매기기
def grade_check(row) :
    mean = (row['math'] + row['english'] + row['science']) / 3
    if mean >= 85 :
        return 'A'
    elif mean >= 70 :
        return 'B'
    elif mean >= 60 :
        return 'C'
    else :
        return 'F'
    
# 정의한 함수(grade_check)를 호출해서 apply() 함수에 적용하기  
exam2['grade'] = exam2.apply(grade_check, axis = 1) # 열의 방향
exam2
# Out:
#     id  nclass  math  english  science grade
# 0    1       1    50       98       50     C
# 1    2       1    60       97       60     B
# 2    3       1    45       86       78     C
# 3    4       1    30       98       58     C
# 4    5       2    25       80       65     F
# 5    6       2    50       89       98     B
# 6    7       2    80       90       45     B
# 7    8       2    90       78       25     C
# 8    9       3    20       98       15     F
# 9   10       3    50       98       45     C
# 10  11       3    65       65       65     C
# 11  12       3    45       85       32     F
# 12  13       4    46       98       65     C
# 13  14       4    48       87       12     F
# 14  15       4    75       56       78     C
# 15  16       4    58       98       65     B
# 16  17       5    65       68       98     B
# 17  18       5    80       78       90     B
# 18  19       5    89       68       87     B
# 19  20       5    78       83       58     B

# %%
exam2.assign(grade = exam2.apply(grade_check, axis = 1))
# Out:
#     id  nclass  math  english  science grade
# 0    1       1    50       98       50     C
# 1    2       1    60       97       60     B
# 2    3       1    45       86       78     C
# 3    4       1    30       98       58     C
# 4    5       2    25       80       65     F
# 5    6       2    50       89       98     B
# 6    7       2    80       90       45     B
# 7    8       2    90       78       25     C
# 8    9       3    20       98       15     F
# 9   10       3    50       98       45     C
# 10  11       3    65       65       65     C
# 11  12       3    45       85       32     F
# 12  13       4    46       98       65     C
# 13  14       4    48       87       12     F
# 14  15       4    75       56       78     C
# 15  16       4    58       98       65     B
# 16  17       5    65       68       98     B
# 17  18       5    80       78       90     B
# 18  19       5    89       68       87     B
# 19  20       5    78       83       58     B

# %%
np.random.seed(10)

df = pd.DataFrame()
df['A'] = np.random.randint(0, 5, size = 5)
df['B'] = np.random.randint(0, 5, size = 5)
df
# Out:
#    A  B
# 0  1  4
# 1  4  1
# 2  0  0
# 3  1  1
# 4  3  2

# %%
# apply - 열
display(df.apply(np.sum, axis = 1))
# apply - 행
display(df.apply(np.sum, axis = 0))
# Out:
# 0    5
# 1    5
# 2    0
# 3    2
# 4    5
# dtype: int64
# A    9
# B    8
# dtype: int64

# %% [markdown]
# #### 집단별(그룹별) 요약 통계 확인 함수
# - df.groupby(), df.agg()
# - groupby() : 집단별로 묶어주는 함수
# - agg() : 요약 통계 구할때 사용하는 함수
#   - 형식 : 요약값 할당할 변수 = ('값을 요약하는데 사용할 변수', '함수')
#   - 전체를 요약한 갑을 구하기보다는 groupby()에 적용해서 집단별 요약값을 구할 때 사용
#   - 사용하는 함수 : mean(), std(), sum(), median(), min(), max(), count()

# %%
# 과정별 모든 컬럼에 대한 평균 한번에 구하기
# groupby()의 기본값 : 기준으로 넣어주는 변수를 인덱스로 바꾸도록 설정 
# ==> as_index = False 설정 : 기준으로 넣어주는 변수(컬럼값)를 인덱스로 
#                             바꾸지 않고 원래대로 유지
exam2.groupby('nclass').mean()
# Out:
#           id   math  english  science
# nclass
# 1        2.5  46.25    94.75    61.50
# 2        6.5  61.25    84.25    58.25
# 3       10.5  45.00    86.50    39.25
# 4       14.5  56.75    84.75    55.00
# 5       18.5  78.00    74.25    83.25

# %%
# nclass별 math의 평균 
exam2[['nclass', 'math']].groupby('nclass').mean()
# Out:
#          math
# nclass
# 1       46.25
# 2       61.25
# 3       45.00
# 4       56.75
# 5       78.00

# %%
# 요약 통계 연결하는 함수 : agg()
exam2.agg(math_mean = ('math', 'mean'))
# Out:
#             math
# math_mean  57.45

# %%
# 반별 수학 평균 구하기
exam2.groupby('nclass').agg(math_mean = ('math', 'mean'))
# Out:
#         math_mean
# nclass
# 1           46.25
# 2           61.25
# 3           45.00
# 4           56.75
# 5           78.00

# %%
exam2
# Out:
#     id  nclass  math  english  science grade
# 0    1       1    50       98       50     C
# 1    2       1    60       97       60     B
# 2    3       1    45       86       78     C
# 3    4       1    30       98       58     C
# 4    5       2    25       80       65     F
# 5    6       2    50       89       98     B
# 6    7       2    80       90       45     B
# 7    8       2    90       78       25     C
# 8    9       3    20       98       15     F
# 9   10       3    50       98       45     C
# 10  11       3    65       65       65     C
# 11  12       3    45       85       32     F
# 12  13       4    46       98       65     C
# 13  14       4    48       87       12     F
# 14  15       4    75       56       78     C
# 15  16       4    58       98       65     B
# 16  17       5    65       68       98     B
# 17  18       5    80       78       90     B
# 18  19       5    89       68       87     B
# 19  20       5    78       83       58     B

# %%
# 여러 요약 통계량을 한번에 구하기

exam2.groupby('nclass').agg(math_mean = ('math', 'mean'), # 반별 수학점수 평균
                            math_sum = ('math', 'sum'),   # 반별 수학점수 합계
                            math_median = ('math', 'median'), # 반별 수학점수 중앙값
                           n_class = ('nclass', 'count'))  # 반별 학생수(빈도)
# Out:
#         math_mean  math_sum  math_median  n_class
# nclass
# 1           46.25       185         47.5        4
# 2           61.25       245         65.0        4
# 3           45.00       180         47.5        4
# 4           56.75       227         53.0        4
# 5           78.00       312         79.0        4

# %%
# 집단별로 그룹지어진 집단을 다시 나누기
# --> groupby()에 여러 컬럼(변수)을 지정하면 집단을 나눈 후 
#    다시 하위 집단으로 나눌 수 있음. 

# 반별 pass, fail 사람수 출력하기
exam_result_cnt = exam.groupby(['nclass', 'result']).agg(result_cnt = 
                                                         ('result', 'count'))
exam_result_cnt
# Out:
#                result_cnt
# nclass result
# 1      pass             4
# 2      fail             1
#        pass             3
# 3      fail             2
#        pass             2
# 4      fail             1
#        pass             3
# 5      pass             4

# %%
# 멀티인덱스(중복 인덱스)일 경우 데이터 접근하기
exam_result_cnt.index
# Out:
# MultiIndex([(1, 'pass'),
#             (2, 'fail'),
#             (2, 'pass'),
#             (3, 'fail'),
#             (3, 'pass'),
#             (4, 'fail'),
#             (4, 'pass'),
#             (5, 'pass')],
#            names=['nclass', 'result'])

# %%
# 4반의 pass한 사람의 수에 접근하려면?
exam_result_cnt.loc[(4, 'pass')]
# Out:
# result_cnt    3
# Name: (4, pass), dtype: int64

# %% [markdown]
# #### 데이터 빈도 구하기
# - value_counts()

# %%
# groupby()로 데이터 분리 - agg()의 count() 함수로 각반의 빈도(학생수)를 구하기
# exam 데이터 활용
exam.groupby('nclass').agg(p_cnt = ('nclass', 'count'))
# Out:
#         p_cnt
# nclass
# 1           4
# 2           4
# 3           4
# 4           4
# 5           4

# %%
# value_counts() 적용한 반별 빈도수
exam['nclass'].value_counts()  # 1차원 시리즈 형태로 출력
# Out:
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# Name: nclass, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 결측치 처리
# - 결측치(missing value) : 누락된 값, 비어 있는 값
# - 수집 과정에서 발생한 오류 때문에 데이터가 비어있는 상태로 수집
# - 결측치가 존재 ==> 함수 적용 불가, 분석 결과 왜곡 문제가 발생
# - 실제 데이터를 분석할 때는 결측치가 있는지 확인 후
# - 제거하거나 데이터 정제값으로 채워준 후에 분석 진행

# %%
# 결측치가 포함된 데이터프레임 만들기
# 넘파이의 np.nan ==> 결측치 생성
df = pd.DataFrame({'gender' : ['m', 'f', np.nan, 'm', 'f'], 
                  'score' : [5, 4, 3, 4, np.nan]})
df
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0
# 4      f    NaN

# %%
# 결측치가 있는 데이터 연산하기
df['score'] + 1
# 결측치가 있는 경우는 연산후 출력결과도 NaN
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# 4    NaN
# Name: score, dtype: float64

# %%
# 결측치 확인하기
pd.isna(df).sum()  # 판다스 함수
# Out:
# gender    1
# score     1
# dtype: int64

# %%
df.isnull().sum() # 판다스 데이터프레임 함수
# Out:
# gender    1
# score     1
# dtype: int64

# %%
# 결측치 채우기 - 평균값
df['score'].mean()
# Out:
# 4.0

# %%
# fillna(값) : 결측치가 있는 곳에 해당하는 값으로 채워줌
df['score'].fillna(4.0)  # inplace = True ==> 변수에 초기화
# Out:
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    4.0
# Name: score, dtype: float64

# %%
df.loc[4, 'score'] = 4.0

# %%
df
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0
# 4      f    4.0

# %% [markdown]
# #### 데이터 삭제
# - 결측치가 있는 행 제거

# %%
df = pd.DataFrame({'gender' : ['m', 'f', np.nan, 'm', 'f'], 
                  'score' : [5, 4, 3, 4, np.nan]})
df
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0
# 4      f    NaN

# %%
# 결측치가 하나라도 있는 행 모두 제거
df.dropna()
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 3      m    4.0

# %%
# score 컬럼을 기준으로 결측치가 있는 행 제거
df.dropna(subset = 'score')
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0

# %%
# 2, 4번 행 제거하기
df.drop(2, axis = 0)
df.drop(4, axis = 0)
df.drop([2, 4], axis = 0)
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 3      m    4.0

# %% [markdown]
# #### 해당하는 컬럼 삭제하기

# %%
# gender 컬럼 삭제하기
df.drop('gender', axis = 1)
df.drop(['gender', 'score'], axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# #### 이상치 처리
# - 정상 범위에서 크게 벗어난 값을 의미 : anomaly
# - 논리적으로 존재할 수 없는 값
# - 값의 범위가 극단적으로 크거나 작은 값 : 극단치(outlier)

# %%
df = pd.DataFrame({'gender' : ['m', 'f', 'ff', 'm', 'f'], 
                  'score' : [5, 4, 3, 4, 3]})
df
# Out:
#   gender  score
# 0      m      5
# 1      f      4
# 2     ff      3
# 3      m      4
# 4      f      3

# %%
# ff 값을 f로 바꾸기  ==> np.where
df['gender'] = np.where(df['gender'] == 'ff', 'f', df['gender'])
df
# Out:
#   gender  score
# 0      m      5
# 1      f      4
# 2      f      3
# 3      m      4
# 4      f      3

# %%
# 극단치 기준값 구하기
# quantile() 함수로 분위수를 구함
pct25 = mpg['hwy'].quantile(.25) # 1사분위수
pct75 = mpg['hwy'].quantile(.75) # 3사분위수
display(pct25)
display(pct75)
# Out:
# 18.0
# 27.0

# %%
# IQR (inter quartile range) : Q3 - Q1, Box plot의 기본이 되는 수치
iqr = pct75 - pct25
iqr
# Out:
# 9.0

# %%
# 하한, 상한 구하기
# 하한 : 1사분위수보다 'IQR의 1.5배만큼 더 작은 값', 최소 제한선
# 상한 : 3사분위수보다 'IQR의 1.5배만큼 더 큰 값', 최대 제한선
display(pct25 - 1.5 * iqr) # 하한
display(pct75 + 1.5 * iqr) # 상한
# Out:
# 4.5
# 40.5

# %%
# 극단치를 결측치로 처리하기 --> 기준값 (4.5 ~ 40.5)을 벗어나면 결측치
mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5), np.nan, mpg['hwy'])

# %%
mpg['hwy'].isnull().sum()
# Out:
# 3

# %%
mpg[mpg['hwy'].isnull()]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33  NaN  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35  NaN  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29  NaN  d
#
#        category
# 212     compact
# 221  subcompact
# 222  subcompact

# %% [markdown]
# #### 카테고리 형식으로 데이터 정리 : cut()

# %%
age = [0,2,15,21,23,37,31,61,20,41,32,100]
labels = ['미성년자', '청년', '중년', '장년', '노년']
# 0 ~ 15, 16 ~ 50, 51 ~ 70, 71 ~ 90, 91 ~ 100
bins = [-1, 15, 50, 70, 90, 100]

cat = pd.cut(age, bins, labels=labels)
cat

df_age = pd.DataFrame(age, columns=['age'])
df_age['category'] = cat
df_age
# Out:
#     age category
# 0     0     미성년자
# 1     2     미성년자
# 2    15     미성년자
# 3    21       청년
# 4    23       청년
# 5    37       청년
# 6    31       청년
# 7    61       중년
# 8    20       청년
# 9    41       청년
# 10   32       청년
# 11  100       노년

# %% [markdown]
# #### 데이터 병합
# - 열 : 가로로 데이터 합침 - merge()
# - 행 : 세로로 데이터 합침 - concat()

# %%
test1 = pd.DataFrame({'id':[1,2,3,4,5],'midterm':[60,80,70,90,85]})
test2 = pd.DataFrame({'id':[1,2,3,4,5],'final':[70,83,65,95,80]})

# %%
display(test1)
display(test2)
# Out:
#    id  midterm
# 0   1       60
# 1   2       80
# 2   3       70
# 3   4       90
# 4   5       85
#    id  final
# 0   1     70
# 1   2     83
# 2   3     65
# 3   4     95
# 4   5     80

# %%
# merge() 
total = pd.merge(test1, test2, how = 'left', on = 'id')
total
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65
# 3   4       90     95
# 4   5       85     80

# %%
# concat()
# 세로로 합하기 위해 특정 컬럼명 변경
group1 = test1.rename(columns={'midterm':'test'})
group2 = test2.rename(columns={'final':'test'})
display(group1)
display(group2)
# Out:
#    id  test
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85
#    id  test
# 0   1    70
# 1   2    83
# 2   3    65
# 3   4    95
# 4   5    80

# %%
tot = pd.concat([group1, group2], ignore_index= True)
tot

# ignore_index= True : 기존에 가지고 있던 인덱스를 무시하고 새로운 인덱스로 부여하겠다
# Out:
#    id  test
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85
# 5   1    70
# 6   2    83
# 7   3    65
# 8   4    95
# 9   5    80
