# %%
import pickle

# %%
# 멜론차트의 데이터를 불러와서 데이터 확인하기
# with문 사용해서 데이터 불러오기

with open('music_100.pkl','rb') as f : # 'rb' = read binary
    music = pickle.load(f)

# %%
music[:5]
# Out:
# [[1, '퀸카 (Queencard)', '(여자)아이들'],
#  [2, 'I AM', 'IVE (아이브)'],
#  [3, 'Spicy', 'aespa'],
#  [4, '이브, 프시케 그리고 푸른 수염의 아내', 'LE SSERAFIM (르세라핌)'],
#  [5, 'UNFORGIVEN (feat. Nile Rodgers)', 'LE SSERAFIM (르세라핌)']]

# %%
s_song= input('제목 중 찾고 싶은 키워드를 입력하세요 >> ')
s_cnt = 0 # 찾은 노래 곡수 담을 변수
song_list = [] #찾은 노래의 순위정보와 노래제목을 담을 빈 리스트


# 인덱스 0 : 차트 순위, 1 : 노래 제목 , 2 : 가수이름
for i in music :
    print(i)
    if s_song in i[1] :
        s_cnt += 1
        song_list.append([i[0], i[1]])      
print(f'\'{s_song}\'으로 검색한 노래 수 : {s_cnt}곡')

print(f'순위와 노래 제목 : {song_list}')
# Out:
# 제목 중 찾고 싶은 키워드를 입력하세요 >> A
# [1, '퀸카 (Queencard)', '(여자)아이들']
# [2, 'I AM', 'IVE (아이브)']
# [3, 'Spicy', 'aespa']
# [4, '이브, 프시케 그리고 푸른 수염의 아내', 'LE SSERAFIM (르세라핌)']
# [5, 'UNFORGIVEN (feat. Nile Rodgers)', 'LE SSERAFIM (르세라핌)']
# [6, 'Kitsch', 'IVE (아이브)']
# [7, 'Hype boy', 'NewJeans']
# [8, '꽃', '지수 (JISOO)']
# [9, '사랑은 늘 도망가', '임영웅']
# [10, '손오공', '세븐틴 (SEVENTEEN)']
# [11, '헤어지자 말해요', '박재정']
# [12, 'Ditto', 'NewJeans']
# [13, '모래 알갱이', '임영웅']
# [14, 'Cupid', 'FIFTY FIFTY']
# [15, '우리들의 블루스', '임영웅']
# [16, '다시 만날 수 있을까', '임영웅']
# [17, 'OMG', 'NewJeans']
# [18, '무지개', '임영웅']
# [19, 'Allergy', '(여자)아이들']
# [20, '사건의 지평선', '윤하 (YOUNHA)']
# [21, '파이팅 해야지 (Feat. 이영지)', '부석순 (SEVENTEEN)']
# [22, "I Don't Think That I Like Her", 'Charlie Puth']
# [23, 'After LIKE', 'IVE (아이브)']
# [24, 'London Boy', '임영웅']
# [25, '이제 나만 믿어요', '임영웅']
# [26, 'Polaroid', '임영웅']
# [27, 'Dangerously', 'Charlie Puth']
# [28, '아버지', '임영웅']
# [29, 'Candy', 'NCT DREAM']
# [30, 'LOVE DIVE', 'IVE (아이브)']
# [31, 'Teddy Bear', 'STAYC(스테이씨)']
# [32, 'Attention', 'NewJeans']
# [33, '인생찬가', '임영웅']
# [34, 'A bientot', '임영웅']
# [35, 'Dynamite', '방탄소년단']
# [36, '물론', '허각']
# [37, '손이 참 곱던 그대', '임영웅']
# [38, '심(心)', 'DK(디셈버)']
# [39, '사랑해 진짜', '임영웅']
# [40, '연애편지', '임영웅']
# [41, 'ANTIFRAGILE', 'LE SSERAFIM (르세라핌)']
# [42, '잠깐 시간 될까', '이무진']
# [43, '사랑..그게 뭔데', '지아']
# [44, '보금자리', '임영웅']
# [45, 'Broken Melodies', 'NCT DREAM']
# [46, 'NIGHT DANCER', 'imase']
# [47, 'Butter', '방탄소년단']
# [48, '사랑하지 않아서 그랬어', '임한별']
# [49, '사람 Pt.2 (feat. 아이유)', 'Agust D']
# [50, 'Take Two', '방탄소년단']
# [51, 'Heaven(2023)', '임재현']
# [52, '사랑인가 봐', '멜로망스']
# [53, 'Like Crazy', '지민']
# [54, '찬란한 하루', '멜로망스']
# [55, '봄날', '방탄소년단']
# [56, '빛이 나는 너에게', '던 (DAWN)']
# [57, '사실말야내가말야그게그러니까말이야', '케이시 (Kassy)']
# [58, '너의 모든 순간', '성시경']
# [59, '건물 사이에 피어난 장미 (Rose Blossom)', 'H1-KEY (하이키)']
# [60, 'Permission to Dance', '방탄소년단']
# [61, 'KNOCK', '이채연']
# [62, '나에게 그대만이', '탑현']
# [63, 'Thirsty', 'aespa']
# [64, 'The Planet', '방탄소년단']
# [65, '첫 키스에 내 심장은 120BPM', '경서']
# [66, "That's Hilarious", 'Charlie Puth']
# [67, 'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)', '정국, 방탄소년단']
# [68, 'Nxde', '(여자)아이들']
# [69, 'TOMBOY', '(여자)아이들']
# [70, '부동의 첫사랑', '10CM']
# [71, 'Angel Pt. 1 (Feat. Kodak Black, NLE Choppa, JVKE, Muni Long)', 'Fast & Furious: The Fast Saga, 지민']
# [72, 'STAY', 'The Kid LAROI, Justin Bieber']
# [73, 'CHRISTIAN', 'Zior Park']
# [74, '사랑의 바보', '제이세라']
# [75, '한사람만 (2023) (여름날 우리 X 이홍기 (FT아일랜드))', '이홍기 (FT아일랜드)']
# [76, '나의 바람 (Wind And Wish)', '비투비']
# [77, '안녕이라고 말하지마', 'V.O.S']
# [78, '해요 (2022)', '#안녕']
# [79, 'FRIEND THE END', '볼빨간사춘기']
# [80, 'Love Me Like This', 'NMIXX']
# [81, '한강에서 (Feat. BIG Naughty)', '폴킴']
# [82, '취중고백', '김민석 (멜로망스)']
# [83, 'LOCKDOWN', '이세계아이돌']
# [84, 'ELEVEN', 'IVE (아이브)']
# [85, '그라데이션', '10CM']
# [86, 'That’s Not How This Works (feat. Dan + Shay)', 'Charlie Puth']
# [87, 'Monologue', '테이']
# [88, '사랑하기 싫어', '지아']
# [89, 'on the street (with J. Cole)', 'j-hope, J. Cole']
# [90, 'FEARLESS', 'LE SSERAFIM (르세라핌)']
# [91, '다정히 내 이름을 부르면', '경서예지, 전건호']
# [92, 'Shut Down', 'BLACKPINK']
# [93, '사랑하지 않아서 그랬니', '지아']
# [94, '정이라고 하자 (Feat. 10CM)', 'BIG Naughty (서동현)']
# [95, '내가 아니라도', '주호']
# [96, 'Say I Love You', '우디 (Woody)']
# [97, 'Pink Venom', 'BLACKPINK']
# [98, '그중에 그대를 만나', '김호중']
# [99, '새삥 (Prod. ZICO) (Feat. 호미들)', '지코 (ZICO)']
# [100, 'Salty & Sweet', 'aespa']
# 'A'으로 검색한 노래 수 : 13곡
# 순위와 노래 제목 : [[2, 'I AM'], [19, 'Allergy'], [23, 'After LIKE'], [32, 'Attention'], [34, 'A bientot'], [41, 'ANTIFRAGILE'], [46, 'NIGHT DANCER'], [67, 'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)'], [71, 'Angel Pt. 1 (Feat. Kodak Black, NLE Choppa, JVKE, Muni Long)'], [72, 'STAY'], [73, 'CHRISTIAN'], [76, '나의 바람 (Wind And Wish)'], [90, 'FEARLESS']]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. 1위곡 삭제
del music[0]

# %%
# 확인
music[:5]
# Out:
# [[2, 'I AM', 'IVE (아이브)'],
#  [3, 'Spicy', 'aespa'],
#  [4, '이브, 프시케 그리고 푸른 수염의 아내', 'LE SSERAFIM (르세라핌)'],
#  [5, 'UNFORGIVEN (feat. Nile Rodgers)', 'LE SSERAFIM (르세라핌)'],
#  [6, 'Kitsch', 'IVE (아이브)']]

# %%
# 1위곡으로 자신의 최애곡 추가
music.append([1, '형', '노라조'])

# %%
# 추가확인
music

# 정렬후 순위별 출력하기

music.sort()

# %%
music
# Out:
# [[1, '형', '노라조'],
#  [2, 'I AM', 'IVE (아이브)'],
#  [3, 'Spicy', 'aespa'],
#  [4, '이브, 프시케 그리고 푸른 수염의 아내', 'LE SSERAFIM (르세라핌)'],
#  [5, 'UNFORGIVEN (feat. Nile Rodgers)', 'LE SSERAFIM (르세라핌)'],
#  [6, 'Kitsch', 'IVE (아이브)'],
#  [7, 'Hype boy', 'NewJeans'],
#  [8, '꽃', '지수 (JISOO)'],
#  [9, '사랑은 늘 도망가', '임영웅'],
#  [10, '손오공', '세븐틴 (SEVENTEEN)'],
#  [11, '헤어지자 말해요', '박재정'],
#  [12, 'Ditto', 'NewJeans'],
#  [13, '모래 알갱이', '임영웅'],
#  [14, 'Cupid', 'FIFTY FIFTY'],
#  [15, '우리들의 블루스', '임영웅'],
#  [16, '다시 만날 수 있을까', '임영웅'],
#  [17, 'OMG', 'NewJeans'],
#  [18, '무지개', '임영웅'],
#  [19, 'Allergy', '(여자)아이들'],
#  [20, '사건의 지평선', '윤하 (YOUNHA)'],
#  [21, '파이팅 해야지 (Feat. 이영지)', '부석순 (SEVENTEEN)'],
#  [22, "I Don't Think That I Like Her", 'Charlie Puth'],
#  [23, 'After LIKE', 'IVE (아이브)'],
#  [24, 'London Boy', '임영웅'],
#  [25, '이제 나만 믿어요', '임영웅'],
#  [26, 'Polaroid', '임영웅'],
#  [27, 'Dangerously', 'Charlie Puth'],
#  [28, '아버지', '임영웅'],
#  [29, 'Candy', 'NCT DREAM'],
#  [30, 'LOVE DIVE', 'IVE (아이브)'],
#  [31, 'Teddy Bear', 'STAYC(스테이씨)'],
#  [32, 'Attention', 'NewJeans'],
#  [33, '인생찬가', '임영웅'],
#  [34, 'A bientot', '임영웅'],
#  [35, 'Dynamite', '방탄소년단'],
#  [36, '물론', '허각'],
#  [37, '손이 참 곱던 그대', '임영웅'],
#  [38, '심(心)', 'DK(디셈버)'],
#  [39, '사랑해 진짜', '임영웅'],
#  [40, '연애편지', '임영웅'],
#  [41, 'ANTIFRAGILE', 'LE SSERAFIM (르세라핌)'],
#  [42, '잠깐 시간 될까', '이무진'],
#  [43, '사랑..그게 뭔데', '지아'],
#  [44, '보금자리', '임영웅'],
#  [45, 'Broken Melodies', 'NCT DREAM'],
#  [46, 'NIGHT DANCER', 'imase'],
#  [47, 'Butter', '방탄소년단'],
#  [48, '사랑하지 않아서 그랬어', '임한별'],
#  [49, '사람 Pt.2 (feat. 아이유)', 'Agust D'],
#  [50, 'Take Two', '방탄소년단'],
#  [51, 'Heaven(2023)', '임재현'],
#  [52, '사랑인가 봐', '멜로망스'],
#  [53, 'Like Crazy', '지민'],
#  [54, '찬란한 하루', '멜로망스'],
#  [55, '봄날', '방탄소년단'],
#  [56, '빛이 나는 너에게', '던 (DAWN)'],
#  [57, '사실말야내가말야그게그러니까말이야', '케이시 (Kassy)'],
#  [58, '너의 모든 순간', '성시경'],
#  [59, '건물 사이에 피어난 장미 (Rose Blossom)', 'H1-KEY (하이키)'],
#  [60, 'Permission to Dance', '방탄소년단'],
#  [61, 'KNOCK', '이채연'],
#  [62, '나에게 그대만이', '탑현'],
#  [63, 'Thirsty', 'aespa'],
#  [64, 'The Planet', '방탄소년단'],
#  [65, '첫 키스에 내 심장은 120BPM', '경서'],
#  [66, "That's Hilarious", 'Charlie Puth'],
#  [67,
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)',
#   '정국, 방탄소년단'],
#  [68, 'Nxde', '(여자)아이들'],
#  [69, 'TOMBOY', '(여자)아이들'],
#  [70, '부동의 첫사랑', '10CM'],
#  [71,
#   'Angel Pt. 1 (Feat. Kodak Black, NLE Choppa, JVKE, Muni Long)',
#   'Fast & Furious: The Fast Saga, 지민'],
#  [72, 'STAY', 'The Kid LAROI, Justin Bieber'],
#  [73, 'CHRISTIAN', 'Zior Park'],
#  [74, '사랑의 바보', '제이세라'],
#  [75, '한사람만 (2023) (여름날 우리 X 이홍기 (FT아일랜드))', '이홍기 (FT아일랜드)'],
#  [76, '나의 바람 (Wind And Wish)', '비투비'],
#  [77, '안녕이라고 말하지마', 'V.O.S'],
#  [78, '해요 (2022)', '#안녕'],
#  [79, 'FRIEND THE END', '볼빨간사춘기'],
#  [80, 'Love Me Like This', 'NMIXX'],
#  [81, '한강에서 (Feat. BIG Naughty)', '폴킴'],
#  [82, '취중고백', '김민석 (멜로망스)'],
#  [83, 'LOCKDOWN', '이세계아이돌'],
#  [84, 'ELEVEN', 'IVE (아이브)'],
#  [85, '그라데이션', '10CM'],
#  [86, 'That’s Not How This Works (feat. Dan + Shay)', 'Charlie Puth'],
#  [87, 'Monologue', '테이'],
#  [88, '사랑하기 싫어', '지아'],
#  [89, 'on the street (with J. Cole)', 'j-hope, J. Cole'],
#  [90, 'FEARLESS', 'LE SSERAFIM (르세라핌)'],
#  [91, '다정히 내 이름을 부르면', '경서예지, 전건호'],
#  [92, 'Shut Down', 'BLACKPINK'],
#  [93, '사랑하지 않아서 그랬니', '지아'],
#  [94, '정이라고 하자 (Feat. 10CM)', 'BIG Naughty (서동현)'],
#  [95, '내가 아니라도', '주호'],
#  [96, 'Say I Love You', '우디 (Woody)'],
#  [97, 'Pink Venom', 'BLACKPINK'],
#  [98, '그중에 그대를 만나', '김호중'],
#  [99, '새삥 (Prod. ZICO) (Feat. 호미들)', '지코 (ZICO)'],
#  [100, 'Salty & Sweet', 'aespa']]

# %%
music.insert(1,[1.5, '뽀로로', 'EBS'])

# %%
music
# Out:
# [[1, '형', '노라조'],
#  [1.5, '뽀로로', 'EBS'],
#  [2, 'I AM', 'IVE (아이브)'],
#  [3, 'Spicy', 'aespa'],
#  [4, '이브, 프시케 그리고 푸른 수염의 아내', 'LE SSERAFIM (르세라핌)'],
#  [5, 'UNFORGIVEN (feat. Nile Rodgers)', 'LE SSERAFIM (르세라핌)'],
#  [6, 'Kitsch', 'IVE (아이브)'],
#  [7, 'Hype boy', 'NewJeans'],
#  [8, '꽃', '지수 (JISOO)'],
#  [9, '사랑은 늘 도망가', '임영웅'],
#  [10, '손오공', '세븐틴 (SEVENTEEN)'],
#  [11, '헤어지자 말해요', '박재정'],
#  [12, 'Ditto', 'NewJeans'],
#  [13, '모래 알갱이', '임영웅'],
#  [14, 'Cupid', 'FIFTY FIFTY'],
#  [15, '우리들의 블루스', '임영웅'],
#  [16, '다시 만날 수 있을까', '임영웅'],
#  [17, 'OMG', 'NewJeans'],
#  [18, '무지개', '임영웅'],
#  [19, 'Allergy', '(여자)아이들'],
#  [20, '사건의 지평선', '윤하 (YOUNHA)'],
#  [21, '파이팅 해야지 (Feat. 이영지)', '부석순 (SEVENTEEN)'],
#  [22, "I Don't Think That I Like Her", 'Charlie Puth'],
#  [23, 'After LIKE', 'IVE (아이브)'],
#  [24, 'London Boy', '임영웅'],
#  [25, '이제 나만 믿어요', '임영웅'],
#  [26, 'Polaroid', '임영웅'],
#  [27, 'Dangerously', 'Charlie Puth'],
#  [28, '아버지', '임영웅'],
#  [29, 'Candy', 'NCT DREAM'],
#  [30, 'LOVE DIVE', 'IVE (아이브)'],
#  [31, 'Teddy Bear', 'STAYC(스테이씨)'],
#  [32, 'Attention', 'NewJeans'],
#  [33, '인생찬가', '임영웅'],
#  [34, 'A bientot', '임영웅'],
#  [35, 'Dynamite', '방탄소년단'],
#  [36, '물론', '허각'],
#  [37, '손이 참 곱던 그대', '임영웅'],
#  [38, '심(心)', 'DK(디셈버)'],
#  [39, '사랑해 진짜', '임영웅'],
#  [40, '연애편지', '임영웅'],
#  [41, 'ANTIFRAGILE', 'LE SSERAFIM (르세라핌)'],
#  [42, '잠깐 시간 될까', '이무진'],
#  [43, '사랑..그게 뭔데', '지아'],
#  [44, '보금자리', '임영웅'],
#  [45, 'Broken Melodies', 'NCT DREAM'],
#  [46, 'NIGHT DANCER', 'imase'],
#  [47, 'Butter', '방탄소년단'],
#  [48, '사랑하지 않아서 그랬어', '임한별'],
#  [49, '사람 Pt.2 (feat. 아이유)', 'Agust D'],
#  [50, 'Take Two', '방탄소년단'],
#  [51, 'Heaven(2023)', '임재현'],
#  [52, '사랑인가 봐', '멜로망스'],
#  [53, 'Like Crazy', '지민'],
#  [54, '찬란한 하루', '멜로망스'],
#  [55, '봄날', '방탄소년단'],
#  [56, '빛이 나는 너에게', '던 (DAWN)'],
#  [57, '사실말야내가말야그게그러니까말이야', '케이시 (Kassy)'],
#  [58, '너의 모든 순간', '성시경'],
#  [59, '건물 사이에 피어난 장미 (Rose Blossom)', 'H1-KEY (하이키)'],
#  [60, 'Permission to Dance', '방탄소년단'],
#  [61, 'KNOCK', '이채연'],
#  [62, '나에게 그대만이', '탑현'],
#  [63, 'Thirsty', 'aespa'],
#  [64, 'The Planet', '방탄소년단'],
#  [65, '첫 키스에 내 심장은 120BPM', '경서'],
#  [66, "That's Hilarious", 'Charlie Puth'],
#  [67,
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)',
#   '정국, 방탄소년단'],
#  [68, 'Nxde', '(여자)아이들'],
#  [69, 'TOMBOY', '(여자)아이들'],
#  [70, '부동의 첫사랑', '10CM'],
#  [71,
#   'Angel Pt. 1 (Feat. Kodak Black, NLE Choppa, JVKE, Muni Long)',
#   'Fast & Furious: The Fast Saga, 지민'],
#  [72, 'STAY', 'The Kid LAROI, Justin Bieber'],
#  [73, 'CHRISTIAN', 'Zior Park'],
#  [74, '사랑의 바보', '제이세라'],
#  [75, '한사람만 (2023) (여름날 우리 X 이홍기 (FT아일랜드))', '이홍기 (FT아일랜드)'],
#  [76, '나의 바람 (Wind And Wish)', '비투비'],
#  [77, '안녕이라고 말하지마', 'V.O.S'],
#  [78, '해요 (2022)', '#안녕'],
#  [79, 'FRIEND THE END', '볼빨간사춘기'],
#  [80, 'Love Me Like This', 'NMIXX'],
#  [81, '한강에서 (Feat. BIG Naughty)', '폴킴'],
#  [82, '취중고백', '김민석 (멜로망스)'],
#  [83, 'LOCKDOWN', '이세계아이돌'],
#  [84, 'ELEVEN', 'IVE (아이브)'],
#  [85, '그라데이션', '10CM'],
#  [86, 'That’s Not How This Works (feat. Dan + Shay)', 'Charlie Puth'],
#  [87, 'Monologue', '테이'],
#  [88, '사랑하기 싫어', '지아'],
#  [89, 'on the street (with J. Cole)', 'j-hope, J. Cole'],
#  [90, 'FEARLESS', 'LE SSERAFIM (르세라핌)'],
#  [91, '다정히 내 이름을 부르면', '경서예지, 전건호'],
#  [92, 'Shut Down', 'BLACKPINK'],
#  [93, '사랑하지 않아서 그랬니', '지아'],
#  [94, '정이라고 하자 (Feat. 10CM)', 'BIG Naughty (서동현)'],
#  [95, '내가 아니라도', '주호'],
#  [96, 'Say I Love You', '우디 (Woody)'],
#  [97, 'Pink Venom', 'BLACKPINK'],
#  [98, '그중에 그대를 만나', '김호중'],
#  [99, '새삥 (Prod. ZICO) (Feat. 호미들)', '지코 (ZICO)'],
#  [100, 'Salty & Sweet', 'aespa']]

# %%
music.extend([1.1, '바보', '븅'],[1,2, '인여진', '김준우'],[1.3, '김현중', '봉민혁'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2888\1413226379.py in <module>
# ----> 1 music.extend([1.1, '바보', '븅'],[1,2, '인여진', '김준우'],[1.3, '김현중', '봉민혁'])
#
# TypeError: list.extend() takes exactly one argument (3 given)
