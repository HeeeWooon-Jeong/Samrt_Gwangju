# %%
team = '봉주르'
print(team+'!')
# Out:
# 봉주르!

# %% [markdown]
# #m:커맨드 모드에서 마크다운 전환 (메모장처럼 글작성 가능, 캡쳐한 이미지 넣기)

# %%
![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 파이썬 변수 06/22
# - 대입
# - 자료형을 선언하지 않음 ==> 동적 자료형

# %%
num = 3
print(num)
print(type(num))
# Out:
# 3
# <class 'int'>

# %% [markdown]
# ### 변수명 규칙
# - 키워드 사용 불가능
# - 함수명으로 변수 사용 가능 --> 파이썬만 가능 권장하지 않음

# %%
import keyword
print(keyword.kwlist)

# 함수를 변수로 사용하면 함수의 본래 기능이 삭제되므로
# 함수를 변수로 사용하는 것은 권장하지 않는다
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
if True :
    print('가즈아')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = 13
num2 = 25
num3 = 77
print(num1, num2, num3)
# Out:
# 13 25 77

# %%
str1 = "Funny python"
str1
# Out:
# 'Funny python'

# %%
str2 = 'Easy python'
str2
# Out:
# 'Easy python'

# %%
str2 = 'Easy python'
str2
# Out:
# 'Easy python'

# %%
str2 = 'Easy python'
type(str2)
# Out:
# str

# %%
a = 10
b = 15
print(a)
print(b)
# Out:
# 10
# 15

# %% [markdown]
# ### 변수 대입 방법

# %%
# a = 10 , b = 15 대입

# %%
a, b = 10 , 15
a, b = b, a # 치환
a , b
# Out:
# (15, 10)

# %%
# 변수 str3, str4 에 'python' 문자열 대입
str3 = 'python'
str4 = 'python'
str3 = str4 = 'python'
str3, str4
# Out:
# ('python', 'python')

# %%
"She's gone"
# Out:
# "She's gone"

# %%
s = '파이썬\n- 동적언어\n- 직관적, 명시적, 간결함'
print(s)
# Out:
# 파이썬
# - 동적언어
# - 직관적, 명시적, 간결함

# %% [markdown]
# - 파이썬에서 사용하는 추가적인 문자열 기호
# - """ """, ''' '''

# %%
# 여러줄의 문장을 하나의 변수에 표현
s = ''' 
파이썬
- 동적언어
- 직관적, 명시적, 간결함'''

# %%
# Out:
# ' \n파이썬\n- 동적언어\n- 직관적, 명시적, 간결함'
