# %% [markdown]
# CBT 2020/06/06<br>
# <br>
# 데이터베이스 설계 단계 수행사항
# - 논리적 데이터 모델로 변환
# - 트랜잭션 인터페이스 설계
# - 개념스키마의 평가 및 정제
#
# 데이터베이스의 설계 단계 순서
# - 개념적 -> 논리적 -> 물리적 설계
#
#
# 네트워크 데이터 모델
# ![image.png](attachment:image.png)
#
# 트리에서의 차수 = 노드에 포함된 개수
# 트리에서의 단말 노드(Terminal Node) = 자식이 하나도 없는 노드
#
# 버블정렬
# ![image-2.png](attachment:image-2.png)
#
# 해싱(Hashing) 에서 한 개의 레코드를 저장할 수 있는 공간을 의미
#
#
#     Bucket : 하나의 주소를 갖는 파일의 한 구역
#     Synonym : 같은 Home Addresss를 갖는 레코드들의 집합
#     Collision : 서로 다른 2개 이상의 레코드가 같은 주소를 갖는 현상
#     Solt : 1개의 레코드를 저장할 수 있는 공간
#
#
# E-R 모델
#
# 개체 타입과 이들 간의 관계 타입을 이용한다.
#
#
# E-R 모델에서는 데이터를 개체,관계,속성으로 묘사
# 현실세계가 내포하는 의미들이 포함된다.
#
#
# - 개체(Entity)타입은  = 사각형
# - 관계(Relationship) 타입은  = 마름모
# - 속성 = 타원
#
#
# 뷰(View)에 대한 설명
#
#
# 실제 저장된 데이터 중에서 사용자가 필요한 내용만을 선별해서 볼 수 있다.
# 데이터 접근 제어로 보안을 제공
# 뷰를 제거할 때는 Drop 문을 사용
# 실제로는 존재하지 않는 가상의 테이블
#
#
# 선형구조 : 선형 리스트(배열), 연결 리스트, 스택, 큐, 데크(Deque)
# 비선형구조 : 트리, 그래프
#
#
# 컴퓨터 명령어 실행주기 중에서 인스트럭션의 종류에 대한 판단이 이루어지는 상태는
#
# fetch -> 다음 실행 명령을 기억장치로부터 cpu로 가져와 명령해독
# indirect -> 오퍼랜드가 지정한 곳부터 "유효주소" 읽어 들이기 위해 메모리 접근
# Execute -> 인출 명령어 이용해 직접 명령어 실행
# Interrupt -> 현재 수행중인 명령이 예기치 않은 일 발생으로 중단된 상태
#
#
# bus를 구성하는데 사용할 수 있는 논리회로는?
# multiplexer
#
# 마이크로 오퍼레이션에 관한 설명 중 옳은 것은?
#
# 마이크로 사이클은 마이크로 오퍼레이션이 이루어지는 주기
#
# 동기방법에는
#
# - 동기 고정식
#
#     동기 고정식은 CPU 시간의낭비를 초래하지만 제어회로가 간단
#
# - 동기 가변식
#
#     동기 가변식은 CPU 시간의 효율적 이용은 가능하나 제어가 복잡
#
# - 비동기식
#
#
# 1개의 Full Adder를 구성하기 위해서는 최소 몇 개의 Half Adder가 있어야 할까
#
#     Half Adder 는 이름 그대로 절반이기 때문에 2개가 있으면 Full Adder가 된다
#
#
# 보조기억장치
# - 주기억 장치에 비해 속도는 느리지만 전원이 차단되어도 내용 유지, 용량이 큼
# - 중앙처리장치와 직접 자료 교환이 불가능
# - 접근 시간이 오래 걸림
# - 일반적으로 주기억장치에 데이터를 저장할 때는 DMA 방식을 사용
# - CPU 가 직접 접근할 수 없다.
#
#
# 채널은 해독, 지시, 실행 기능이 이씅며 데이터 저장하는건 기억장치의 몫
#
# ALU의 위치와 기능이 바르게 나열된것
# ALU(Arithmetic Logic Unit) : CPU 산술 논리 연산 장치
#
#
#
#
#     캐시 메모리는 CPU 처리속도와 주기억장치의 접근 속도 차이를 줄이기 위해 사용하는 고속 Buffer Memory
#
#     캐시는 주기억장치와 CPU사이에 위치하며, 자주 사용하는 프로그램과 데이터를 기억
#
#     캐시메모리는 메모리 계층 구조에서 가장 빠른 소자이며, 처리속도가 거의 CPU속도와 비슷할 정도의 속도를 가지고 있다
#
#     캐시메모리를 사용하면 주 기억장치를 접근하는 횟수가 줄어들어 컴퓨터의 처리속도가 향상
#
#     캐시 주소표는 검색시간을 단축시키기 위해 주로 연관 기억장치를 사용
#
#
#
# 분기 명령이 수행될 때 내용이 바뀌는 것은?
#
# - 프로그램 카운터, 프로그램 계수기 :
#
#         - 다음번에 실행할 명령어의 번지를 기억하는 레지스터
#         - 분기 명령이 실행되는 경우 그 목적지 주소로 갱신됨
#
#
# 수치적인 산술 연산 : ADD, SUB, MUL, DIV, 산술 Shift 등
# 비수치적인 논리 연산 : NOT, AND ,OR ,XOR, 논리적 Shift, Rotate, Complement, Clear 등
#
# op-code가 8 비트일 때 생성 될 수 있는 명령어의 수
#
# 연산자부(op-code)의 크기(비트 수) 표현할 수 있는 명령의 종류를 나타내는 것
# n Bit면 최대 2의 n승개의 명령어를 사용할 수 있다.
#
#
# 기억장치 계층 구조 상 접근 속도가 가장 빠른것
#
# - Register > RAM > ROM > 자기디스크
#
#
# 중앙 처리 장치를 통하지 않고 직접 주기억장치에 접근하여 입출력을 하는 방식으로, 한번에 한 블록씩 전송하는 방법
#
# - DMA : Direct Memory Access
#
#
# 트랩(Trap)의 발생 원인으로 옳은 것
#
#
# - 내부인터럽트(Internal Imterrupt) : 프로세스 내부에서 발생하는 인터럽트(="트랩"이라 불림)
#
#         - 0으로 나누기 인터럽트
#         - Overflow, Underflow 인터럽트
#         - 불법적인 명령어 사용 인터럽트
#         - 보호 공간 접근 인터럽트
#
#
# 색인 구역 (Index Area) : 기본 구역에 이쓴ㄴ 레코드들의 위치를 찾아가는 색인이 기록되는 부분으로
#
#
# 트랙(Track)
# 색인 구역
# 실린더(Cylinder) 색인 구역
# 마스터(master)
#
# 색인 순차파일(Index Sequential File)
#
#
# 순서도와는 달리 논리 기술에 중점을 두고 상자 도형을 이용한 설계 도구로 순차, 선택 ,반복 등의 제어 논리 구조를 표현하는 도구는?
#
# 구조적 설계 도구로 논리기술, 상자도형 = N-S 차트
#
#
# 결합도 : 두 모듈 간의 상호 의존도를 측정
#
#         결합도가 낮을수록 모듈의 독립성은 높아진다.
#
#         결합도의 순서(강->약)
#         내용 -> 공통 -> 외부 -> 제어 -> 스탬프 -> 자료
#         내부공사는 외제 를 스자
#
#
# 순차코드(Sequence code) : 자료의 발생 순서, 크기 순서 등 일정 기준에 따라서 최초의 자료부터 차례로 일련 번호를 부여
#
#
# 표의숫자코드(significant digit code) : 코드화 대상 항목의 성질, 즉 길이, 넓이, 부피, 지름, 높이 등의 물리적 수치를 그대로 코드에 적용
#
#
# 블록코드(Block code) : 코드화 대상 항목 중에서 공통성이 있는 것끼리 블록으로 구분, 각 블록 내에서 일련 번호를 부여한느 방법
#
#
# 기호코드(mnemonic code) : 코드화 대상 항목의 명칭이나 약호와 관계있는 숫자나 문자, 기호를 이용하여 코드를 부여하는 방법(연상코드)
#
#
# 전위오류(Transposition Error) : 좌우 자리 바뀜
# 필사 오류(Transcription Error) : 한자리 잘못
# 임의 오류(Random Error) : 2가지 이상 오류 발생
# 이중 오류(Double Transposition Error) : 전위 오류 2개 이상
#
#
# 프로세스의 표준 처리 패턴 중 어떤 파일에서 특정한 조건에 만족하는 정보를 추출해 내는 처리는??
#
# - 프로세스 표준 패턴
#
#
#         매체변환(Conversion) : 사람이 판독가능 매체와 컴퓨터 저장장치인 파일매체 사이의 상호 간 변화
#         병합(Merge) : 두 개 이상 입력 자료 파일을 하나의 파일로 통합
#         갱신(Update) : 마스터파일 내용을 트랜잭션 파일 내용으로 변경해 새 마스터 파일을 생성
#         분류(Sort) : 비순서적 자료파일을 순서적(오름차순,내림차순)으로 나열
#         조합(Collate) : 파일 내 자료와 대조파일 내 자료가 같은 것끼리 모아 새로운 파일을 만드는 것
#         추출(Extract) : 자료 파일 내 있는 자료 중 조건 맞는 것만 추출
#         분배(Distribution) : 조건 맞는것과 맞지 않는 것으로 분리
#
#
# 데이터파일 종류
#
# - 원시자료파일(Source Data File) : 원시데이터를 적당한 매체에 수록한 입력 데이터 파일
# - 마스터파일(Master File) : 전표처리에서 원장 또는 대장에 해당하는 파일  - 트랜잭션파일(Transaction File) : 마스터파일을 갱신 또는 조회(Update)
# - 히스토리파일(History File) : 사고 발생 시 , 데이터를 원상 복구 위한 보관용 파일
# - 요약파일(History File) : 편리한 집계 위해 다른 파일의 합계를 모아둔 파일
# - 트레일러 파일(Trailer File) : 마스터파일을 양방향레코드로 작성하여 2개로 작성한 파일
#
#
# 부호 검사(Sign Check = Plus-Minus Check) : 계산 결과가 양수 또는 음수인지를 검사
# 중복 레코드 검사(Double Record Check) : 계산을 처리하는 과정에서 동일한 레코드가 있는지를 검사
# 불일치 레코드 검사(Unmatch Record Check) : 마스터 파일과 트랜잭션 파일을 조합할 때 키 항목이 일치하는지의 여부를 검사
# 오버플로 검사(Overflow Check) : 계산 결과가 규정된 자릿수 또는 한계를 초과하는지를 검사
# 제로 균형 검사(Zero Balance Check) : 계산 결과가 0이 되는지를 검사
# 불능 검사(impossible Check) : 0으로 나누는 경우가 있는지를 검사
#
#
# 교착상태 발생의 필요조건
#
# 상호 배제 : 한번에 한개의 프로세스만 공유자원 사용 가능
# 환형 대기 : 공유자원과 공유자원을 사용하기 위해 대기하는 프로세스들이 원형으로 구성
# 비선점 : 다른 프로세스에 할당된 자원을 사용종료될때 까지 강제로 못 뺏음 점유 및 대기 : 자원을 가지고 있는 상태에서 다른 프로세스가 사용하고 있는 자원의 반납을 기다리는 것
#
# 교착상태 해결 방법
# - 교착상태 예방(Deadlock Prevention)  :  교착상태 발생 5가지 조건 부정
# - 교착상태 회피(Deadlock Avoidance)  :  은행원 알고리즘 (Banker's Algorithm)
# - 교착상태 발경 및 회복
#
# RR(Round Robin) 방식은 선점 스케줄링 방식의 하나
#
#     시분할 시스템을 위해 고안된 방식이다
#     시스템이 사용자에게 적합한 응답시간을 제공해 주는 대화식 시스템에 유용
#     시간 할당량이 클 경우 FCFS 기법과 같아지고, 시간 할당량이 작을 경우 문맥 교환 및 오버헤드가 자주 발생될 수 있다
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# 매크로 정의인식, 정의저장, 호출인식--매크로 프로세서
#
# 분산 처리 시스템 - 성형(Star) 연결에 대한 설명
# ![image-9.png](attachment:image-9.png)
#
# 운영체제가 CPU 스케줄링 기법으로 HRN 방식
# ![image-10.png](attachment:image-10.png)
#
# Shannon의 표본화정리
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
#
# HDLC 프레임 구조의 순서
# ![image-13.png](attachment:image-13.png)
#
# 800baud의 변조속도로 4상 위상 변조된 테이터의 신호속도(bps) = 1600
# ![image-14.png](attachment:image-14.png)
#
# FM에서 변조지수가 10, 변조신호의 최고 주파수를 4kHz라 할 때 소요 대역폭 [kHz]은? == 88
#
# ![image-15.png](attachment:image-15.png)
#
#
# ![image-16.png](attachment:image-16.png)
#
#
# ![image-17.png](attachment:image-17.png)
#
#
# Link State
# ![image-18.png](attachment:image-18.png)
#
#
# ![image-19.png](attachment:image-19.png)
#
# 위상변화를 작게 하면서 반송파의 진폭도 바꿔 정보 전송률을 높이려는 변조방식
# = QAM
# ![image-20.png](attachment:image-20.png)
#
# ![image-21.png](attachment:image-21.png)
#
# PCM 방식의 데이터 전송 순서
# 표 양 부 복
# 표본화 -> 양자화 -> 부호화 -> 복호화
#
# ARQ(Automatic Repeat reQuest)  :  자동 반복 요청
#
# ![image-22.png](attachment:image-22.png)
#
# IP 주소 체계에서 B 클래스의 주소 범위는
#
# ![image-23.png](attachment:image-23.png)
#
#
# Locking의 범위 : 데이터베이스 -> 파일 -> 테이블 -> 레코드순으로 작아진다
# Locking 범위가 클수록 데이터베이스 공유도가 감소(병행성 수준이 낮아짐), 로킹 오버헤드가 감소한다.
# Locking 범위가 작을수록 데이터베이스 공유도가 증가한다(병행성 수준이 높아짐), 로킹 오버헤드가 증가한다.
#
# 시스템 카탈로그
# 시스템 자체에 관련 있는 다양한 객체에 관한 정보를 포함하는 시스템 데이터베이스  카탈로그들이 생성되면 자료 사전에 저자오디기 때문에  좁은 의미로는 자료 사전이라고도 한다
# 기본 테이블, 뷰, 인덱스, 패키지, 접근 권한등의 정보를 저장한다
# 무경성 확보를 위하여 일반 사용자가 내용을 검색할 수 있다
#
# 관계해석에 대한 설명
# 관계 데이터의 연산을 표현하는 방법
# 튜플 관계해석과 도메인 관계해석이 있다.
# 관계대수로 표현한 식은 관계해석으로 표현할 수 있다.
#
# ![image-24.png](attachment:image-24.png)
#
# 데이터베이스 3단계 구조 중 사용자나 응용프로그래머가 사용할 수 있도록 데이터베이스를 정의한 것
#
# ![image-25.png](attachment:image-25.png)
#
#
# ![image-26.png](attachment:image-26.png)
#
#
# ![image-27.png](attachment:image-27.png)
#
# E-R 다이어그램에서 개체를 의미하는 기호
# ![image-28.png](attachment:image-28.png)
#
# ![image-29.png](attachment:image-29.png)
#
# IEEE754 에서 규정한 부동소수점 표현 방법에서 비트 형식
#
# 부동소수점 연산의 일반적인 형식은 '부호 지수부 가수부' 이다
#
# ![image-30.png](attachment:image-30.png)
#
# ![image-31.png](attachment:image-31.png)
#
# ![image-32.png](attachment:image-32.png)
#
# ![image-33.png](attachment:image-33.png)
#
# ![image-34.png](attachment:image-34.png)
#
# ![image-35.png](attachment:image-35.png)
#
# - 데이터를 오프라인 장치 또는 액세스의 우선순위가 낮은 장치부터 온라인 장치 또는 우선순위가 높은 장치로 옮기는 것
# - 대용량 기억장치상의 데이터를 직접 접근 기억장치로 옮기는 것
#
# ![image-36.png](attachment:image-36.png)
#
# ![image-37.png](attachment:image-37.png)
#
#
# //db
# 절차형 SQL
# ![image-38.png](attachment:image-38.png)
#
# ![image-39.png](attachment:image-39.png)
#
#
#
#
# ![image-40.png](attachment:image-40.png)
#
#
# ![image-41.png](attachment:image-41.png)
#
# ![image-42.png](attachment:image-42.png)
#
# ![image-43.png](attachment:image-43.png)
#
# ![image-44.png](attachment:image-44.png)
#
# ![image-45.png](attachment:image-45.png)
#
# 나시 슈나이더만은 구조적 프로그래밍 기법이다
#
# ![image-46.png](attachment:image-46.png)
#
# ![image-47.png](attachment:image-47.png)
#
# ![image-48.png](attachment:image-48.png)
#
# Mnemonic - 연상
# ![image-49.png](attachment:image-49.png)
#
#
# ![image-50.png](attachment:image-50.png)
#
# ![image-51.png](attachment:image-51.png)
#
# 테스트 단계 중 시스템을 당장 사용할 수 있도록 준비되어 있는지 확인하기 위한 단계 베타 테스트가 포함된 테스트 단계
# ![image-52.png](attachment:image-52.png)
#
# ![image-53.png](attachment:image-53.png)
#
# 구역성(Locality)에 대한 설명
# - 구역성의 종류로는 시간(temporal) 구역성과 공간(spatial) 구역성이 있다
# - 공간 구역성은 기억장소가 참조되면 그 근처의 기억장소가 다음에 참조되는 경향이 있음을 나타내는 이론
# - 일반적으로 공간 구역성의 예는 배열순례(Array-Traversal), 순차적 코드의 실행 등이 있다.
#
# - 일정시간 동안에 참조한느 페이지의 집합은 '워킹 셋(Working Set)' 입니다.
#
# ![image-54.png](attachment:image-54.png)
#
# 파일을 구성하는 기본적인 자료항목
# - 파일은 사용자가 작성한 서로 관련있는 레코드의 집합체
#
# 라운드로빈 방식은 시분할 시스템
#
# ![image-55.png](attachment:image-55.png)
#
# ![image-56.png](attachment:image-56.png)
#
# ![image-57.png](attachment:image-57.png)
#
# ![image-58.png](attachment:image-58.png)
#
# ![image-59.png](attachment:image-59.png)
#
# ![image-60.png](attachment:image-60.png)
#
# ![image-61.png](attachment:image-61.png)
#
# ![image-62.png](attachment:image-62.png)
#
# ![image-63.png](attachment:image-63.png)
#
# ![image-64.png](attachment:image-64.png)
#
# 패킷 교환방식에 대한 설명
# - 교환기에서 패킷을 일시 저장 후 전송하는 축적교환 기술
# - 패킷처리 방식에 따라 데이터그램과 가상회선 방식이 있다
# - 패킷 교환망에서 DTE와 DCE 간 인터페이스를 위한 프로토콜로 X.25가 있다
#
# - 고정된 대역폭으로 데이터를 전송하는건 회선 교환 방식
#
# LAN의 토폴로지 형태
# ![image-65.png](attachment:image-65.png)
#
#
# TCP 헤더의 플래그 비트에 해당되지 않는 것
# ![image-66.png](attachment:image-66.png)
#
# 데이터통신에서 양방향으로 동시에 송 수신이 가능한 전송방식
# ![image-67.png](attachment:image-67.png)
#
#
# 변조속도가 1600(baud)이고 트리비트(tribit)를 사용한다면 전송속도(bps)는?
# 1 Baud의 시간동안 2bit 가 전송됩니다.
# Tribit는 1 Baud에 3bit를 부여하는 변조 기술
# 따라서 Baud rate의 3배인 1600 * 3 = 4800(bps) 가 됩니다.
#
# ![image-68.png](attachment:image-68.png)
#
# ![image-69.png](attachment:image-69.png)
#
#
# 정처기 22/04/24
#
# 순차 다이어그램은 행위 다이어그램이므로 동적이고, 순차적인 표현을 위한 다이어그램이다.
#
# UML(Unified Modeling Language) 다이어그램은 소프트웨어 시스템을 시각적으로 표현하기 위한 표준화된 언어입니다. UML은 시스템의 구조, 동작, 상호작용 등을 표현하기 위해 사용됩니다.
#
# 애자일(Agile) 방법론은 소프트웨어 개발을 위한 유연하고 반복적인 접근 방식을 지향하는 개발 방법론의 종합적인 용어입니다. 애자일 방법론은 예측 불가능한 환경에서 요구사항의 변화에 신속하게 대응하고 고객의 가치를 최대화하기 위해 개발 프로세스를 조정합니다. 이 방법론은 팀 기반의 협력, 적극적인 피드백 수용, 반복적인 개선 등을 강조합니다.
#
# - 스크럼: 주기적으로 짧은 회의 문제해결
# - 익스트림 프로그래밍 : 개발자들이 소프트웨어 개발을 빠르고 유연하게 진행하기 위함
# - 칸반 : 작업의 흐름을 시각화 하고 제어하는 방법론 칸반보드 칸반카드로 작업의 진행 상태 확인하며 작업량 조절
# - 리크리에이션 : 낭비를 제거하고 가치를 창출하는 방법론 고객의 요구사항 최우선
#
# 유스케이스의 구성 요소 간의 관계
# - 연관관계 : 유스케이스와 액터간의 상호작용이 있음을 표현한다.
# - 포함관계 : 하나의 유스케이스가 다른 유스케이스의 실행을 전제로 할 때 형성되는 관계이다.
# - 확장 관계 : 확장 기능 유스케이스와 확장 대상 유스케이스 사이에 형성 되는 관계
# - 일반화 관계 : 유사한 유스케이스 또는 액터를 모아 추상화한 유스케이스 또는 액터와 연결시켜 그룹을 만들어 이해도를 높이기 위한 관계
#
#
# 기능적 요구사항 VS 비기능적 요구사항
#
# - 기능적 요구사항 : 시스템이 실제로 어떻게 동작하는지에 관점을 둔 요구사항
# - 비기능적 요구사항 : 시스템 구축에 대한 성능, 보안, 품질, 안정 등에 대한 성능, 보안, 품질, 안정성등으로 실제 수행에 보조적인 요구사항
#
# 미들웨어(Middleware)
# - 여러 운영체제에서 응용 프로그램들 사이에 위치한 소프트웨어이다.
# - 소프트웨어 컴포넌트를 연결하기 위한 준비된 인프라 구조를 제공한다.
# - 여러 컴포넌트를 1대 1, 1대 다, 다대 다 등 여러 가지 형태로 연결 가능
#
# 명백한 역할을 가지고 독립적으로 존재할 수 있는 시스템의 부분으로 넓은 의미에서는 재사용되는 모든 단위라고 볼 수 있으며, 인터페이스를 통해서만 접근할 수 있는 것은?
#
# Component
#
#
# GoF(Gang of Four) 디자인 패턴을 생성, 구조, 행동 패턴의 세 그룹으로 분류
# - Adapter 패턴
# - Bridge 패턴
# - Proxy 패턴

# %% [markdown]
# 운영체제의 개요
#
# - 시스템의 자원들을 효율적으로 관리
# - 편리하고 효과적으로 사용할 수 있도록 환경 제공
#
# 운영체제의 목적
#
# - 처리능력
# - 반환시간 단축
# - 사용 가능도
# - 신뢰도
#
# 운영체제의 기능
#
# - 프로세서/기억장치/입.출력장치, 파일, 정보 자원관리
# - 자원의 스케줄링 기능을 제공
# - 인터페이스 제공
# - 공유 기능을 제공
#
# 운영체제 운용 기법
#
# - 실시간 처리 시스템 : 데이터가 생겨날 때마다 바로 처리
# - 분산 처리 시스템 : 지역적으로 분산된 여러 대의 컴퓨터를 연결하여 작업을 분담하여 처리
# - 다중 프로그래밍 시스템 : 한개의 cpu로 여러 개의 프로그램을 동시에 처리
# - 다중 처리 시스템 : 하나의 컴퓨터에 여러 개의 CPU를 설치하여 프로그램 처리
# - 임베디드 시스템 : 특정 기능을 수행하는 응용 프로그램을 탑재하여 기능을 수행
#
#
# 운영체제 운용 기법의 발달 과정
#
# - 1세대 일괄처리 시스템
# - 2세대 다중 프로그래밍 /다중 처리 시스템 / 시분할 시스템 / 실시간 처리 시스템
# - 3세대 다중모드
# - 4세대 분산 처리 시스템
#
#
# 프로세스의 정의
#
# - PCB를 가진 프로그램
# - 주기억장치에 저장된 프로그램
# - 프로세서가 할당되는 실체
# - 프로시저가 활동중인 것
# - 비동기적 행위를 일으키는 주체
# <!--  비동기적 행위(Asynchronous Behavior)는 일련의 작업이 순차적으로  -->
# <!--  진행되지 않고, 병렬 또는 동시에 실행되는 행위를 의미합니다.  -->
# - 지정된 결과를 얻기 위한 일련의 계통적 동작
# - 목적 또는 결과에 따라 발생되는 사건들의 과정
#
# 프로세스 상태 전이
#
# - 제출(Submit) : 작업을 제출한 상태
# - 접수(Hold) : 제출된 작업이 저장된 상태
# - 준비 : 프로세서를 할당받기 위해 대기상태
# - 대기(Wait), 보류, 블록 : 입.출력 처리가 완료될 때까지 대기하고있는 상태
# - 종료(Terminated, Exit) : 실행이 끝나고 할당이 해제된 상태
#
# ### 스케줄링
# #### FCFS(FIFO)
#
# 도착한 순서에 따라 차례로 CPU를 할당
#
# ![image.png](attachment:image.png)
#
# #### SJF
# 실행 시간이 가장 짧은  프로세스에게 먼저 CPU를 할당
#
# ![image-2.png](attachment:image-2.png)\
#
# #### RR(Round Robin)
#
# - 시분할 시스템을 위해 고안
# - FCFS 알고리즘을 선점 형태로 변형
# - 시간이 클 경우 FCFS 기법과 같아짐
#
#
#
#
# 교착상태 발생의 필요 충분 조건
# - 상호 배제(Mutual Exclusion) : 한 번에 한 개의 프로세스만 사용
# - 점유와 대기(Hold and Wait) : 하나의 자원을 점유하고 사용되고 이쓴 자원을 추가로 점유를 위해 대기하는 프로세스가 있어야함
# - 비선점(Non - preemption) : 할당된 자원을 강제로 뺏지 못함
# - 환형 대기(Circular Wait) : 대기하는 프로세스들이 원형으로 구성
#
#
# 기억장치의 배치 전략
#
# - 최초 적합(First Fit) : 첫 번째 분할 영역에 배치
# - 최적 적합(Best Fit) : 단편화를 가장 작게 남기는 영역 배치
# - 최악 적합(Worst Fit) : 단편화를 가장 많이 남기는
#
#
# 가상기억장치 - 페이징 기법
#
# - 프로그램과 주기억장치의 영역 동일한 크기로 나눈 후 적재
# - 프로그램을 일정한 크기로 나눈 단위를 페이지
# - 내부 단편화가 발생 가능
#
#
# 가상기억장치 - 세그먼테이션 기법
#
# - 다양한 크기의 논리적인 단위로 나눈 후 적재
# - 논리적인 크기로 나눈 단위 = 세그먼트
# - 외부 단편화 발생 가능
#
# 주요 페이지 교체 알고리즘
#
# - FIFO : 가장 먼저 들어와서 가장 오래 있었던 페이지를 교체
# - LRU : 가장 오랫동안 사용하지 않은 페이지를 교체
# - NUR : 최근에 사용하지 않은 페이지를 교체, 참조비트와 변형 비트가 사용됨
#
#
# 주요 디스크 스케줄링
#
# - FCFS
#     가장 먼저 들어온 트랙에 대한 요청을 먼저 서비스
# - SSTF
#     탐색 거리가 가장 짧은 요청 먼저 서비스
#
# ![image-3.png](attachment:image-3.png)
#
# 직접 파일(Direct File)
# - 레코드를 임의의 물리적 저장공간에 기록
# - 해싱 함수를 이용하여 물리적 상대주소 계산
#
#
# 2단계 디렉터리
#
# - 2계층 구조
#     중앙에 마스터 파일 디렉터리
#     그 아래에 서로 다른 파일 디렉터리
# - 마스터 파일 디렉터리 = 사용자 파일 디렉터리 관리
# - 사용자 파일 디렉터리 = 사용자별 파일 관리
#
#
# 권한(자격) 리스트
#
# - 영역을 중심으로 권한 리스트를 구성
# - 객체와 그 객체에 허용된 조작 리스트로 구성
#
# ### UNIX
#
# #### UNIX의 특징
# - 대부분 C언어로 되어있어 **이식성이 높다**
# - 호환성이 높다
# - 다중 사용자(Multi-User), 다중 작업(Multi-Tasking)지원
# - 트리 구조
#
#
# #### UNIX - 커널(Kernel)의 기능
# - 프로세스(CPU 스케쥴링)
# - 기억장치 관리
# - 파일 시스템 관리
# - 입.출력 관리
#
# #### UNIX- 쉘(Shell)
# - 명령어 해석기
# - 시스템과 사용자간의 인터페이스
#
# #### UNIX 주요 명령어
# - cat : 파일 내용 표시
# - chmod : 보호모드 설정 **파일의 사용 허가를 지정**
# - chown : 소유자 변경
# - exec : 새로운 프로세스 수행
# - fork : 새로운 프로세스를 생성
# - ls : 파일목록 확인
#
#
#
# 비동기식 전송
# - 시작 비트와 정지 비트를 붙여서 전송
# - 휴지 시간이 불규칙
#
#
# 해밍코드
# - 오류가 발생한 비트 검출 직접 수정
# - 1비트의 오류만 수정 가능
#
#
# 통신 프로토콜
# - 데이터 교환을 정확하고 원활하게 수행 표준화된 통신 규약
#
#
# ### OSI 7 계층 (1 -> 7)
#
#     1. 물리 계층
#     2. 데이터 링크 계층
#     3. 네트워크 계층
#     4. 전송 계층
#     5. 세션 계층
#     6. 표현 계층
#     7. 응용 계층
#
#
# #### 주요계층
# - 데이터 링크 계층 : 신뢰성 있고 효율적인 정보 전송 연결 설정과 유지및 종료
# - 네트워크 계층 : 네트워크 연결을 관리  데이터의 교환 및 중계
# - 전송 계층 : 종단 시스템간 투명한 데이터 전송을 담당
#
#
# X.25의 계층 구조
#
# - 물리
# - 프레임
# - 패킷
#
#
# TCP/IP 계층별 주요 프로토콜
#
# 응용 계층 : TELNET/FTP/SMTP/SNMP/E-MAIL
# 전송 계층 : TCP/UDP
# 인터넷 계층 : IP/ICMP/IGMP/ARP/RARP 등
# 네트워크 액세스 계층 : Ethernet/ IEEE 802/ HDLC/ X.25/ RS-232C 등
#
#
#
# 경로 제어(라우팅) 프로토콜
#
# - 종류 : RIP/OSPF/EGP/BGP/EIGRP 등
# - 거리 벡터 방식 : RIP/EIGRP/BGP
# - 링크 상태 방식 : OSPF
#
#
# 패킷 교환 방식
# - 패킷으로 잘라서 전송
# - 데이터 전송  적합
# - 경로를 선택하여 우회
# - 대량의 데이터 전송 지연이 많아짐
#
#
#
# 고속 이더넷
# - 100 BASE T라고도 부림
# - CSMA/CS  UTP케이블  100Mbps의 속도로 전송
#
#
# IPv6
#
# - 총 128비트
# - 16진수 : 으로 구분
# - 인증성, 기밀성, 무결성 지원 으로 보안문제 해결
# - 확장성 융통성 연동성 뛰어남
#
#
# 소프트웨어 공학의 기본 원칙
# - 현대 프로그래밍 기술을 **계속적으로 적용**
# - 품질 **지속적으로 검증**
# - 개발 관련 사항 및 결과 **명확한 기록**
#
#
#
# 폭포수 모형
# - 이전 단계로 돌아갈 수 없다
# - 고전적 생명 주기 모형
# - 요구사항 반영 어려움
#
#
# 나선형 모형
# - 점진적으로 완벽한 최종 소프트웨어를 개발
# - 계획 수립 -> 위험 분석 -> 개발 및 검증 -> 고객 평가
#
#
# 애자일 개발 4가지
# - 개인과 상호작용에 더 가치를 둠
# - 실행되는 SW에 더 가치
# - 고객과 협업에 더 가치
# - 변화에 반응하는 것에 더 가치
#
#
# XP의 핵심 가치
# - 의사소통
# - 단순성
# - 용기
# - 존중
# - 피드백
#
#
# ![image-4.png](attachment:image-4.png)
#
#
# 자료 사전의 표기 기호
#
# - = : 정의
# - + : 연결
# - () : 생략
# - [|] : 선택
# - {} : 반복
# - ** : 설명
#
#
#
# ### UML
#
# - 의사소통이 원활하게 이루어지도록 표준화
# - 객체지향 모델링 언어
# - 구성 요소 :  사물/ 관계 / 다이어그램
#
# #### UML의 주요관계
#
# - 일반화 관계 : 하나의 사물이 다른 사물에 비해 더 **일반적인지 구체적인지 표현**
#
# - 의존 관계 : 서로에게 **영향을 주는 시간 동안만 연관을 유지**하는 관계
# - 실체화 관계 : 서로를 그룹화 할 수 있는 관계
#
#
# 소프트웨어 아키텍쳐 뷰의 종류
#
# - 유스케이스 (Use Case) 뷰
# - 논리적 (Logical) 뷰
# - 구현 (Implementaiton) 뷰
# - 프로세스(Process) 뷰
# - 배포(Deployment) 뷰
#
#
# 파이프 - 필터 패턴
#
# - 파이프를 통해 데이터를 전송
# - 입력 데이터 처리 결과를 다음 서브 시스템으로 넘겨주는 과정을 반복
#
#
# 메소드
#
# - 객체의 구체적인 연산 정의
#
# 클래스
#
# - 공통된 속성과 연산 객체의 집합
# - 클래스에 속한 각각의 객체 인스턴스
#
#
# 추상 클래스
#
# - 공통점만을 모아 추상화한 클래스
# - 인스턴스 생성이 불가능
#
#
# 캡슐화
#
# - 데이터와 함수를 하나로 묶는 것
# - 외부 모듈의 변경으로 인한 **파급 효과가 적음**
# - 재사용 용이
#
#
# 상속
#
# - 상위 클래스의 모든 속성과 연산 물려받는것
#
# ### 생성패턴
# #### 빌더(Builder)
#
# - 인스턴스 조합하여 객체 생성
# - 생성과정과 표현 방법을 분리 하고있음
#
#
# #### 프로토타입(Prototype)
#
# - 원본 객체를 복제하여 객체 생성
# - 비용이 큰 경우 이용
#
#
# #### 싱글톤(Singleton)
#
# - 생성된 객체를 어디서든 참조/동시에 참조 할수는 없다
# - 메모리낭비 최소화
#
#
# ### 구조패턴
#
# ####  데코레이터(Decorator)
#
# - 능동적으로 기능들을 확장/ 다른 객체들을 덧붙이는 방식으로 구현
#
# 화이트박스 테스트
#
# - 원시 코드의 논리적인 모든 경로를 테스트
# - 모든 문장을 한 번 이상 실행
#
# 화이트박스 테스트 - 루프검사
#
#
# - 프로그램의 반복 구조에 초점을 맞춰 실시하는 기법
# - 반복구조 : 단순루프/중첩루프/연결루프/비구조적루프
#
#
# 블랙박스 테스트 종류
#
# - 동치 분할 검사
# - 경계값 분석
# - 원인-효과 그래프 검사
# - 오류 예측 검사
# - 비교검사
#
#
# 소프트웨어 테스트 순서
#
#     1. 단위 테스트
#     2. 통합 테스트
#     3. 시스템 테스트
#     4. 인수 테스트
#
#
# 단위 테스트
# -  모듈이나 컴포넌트에 초점을 맞춰 테스트
# - 기능성 테스트를 최우선
#
# 통합 테스트
#
# - 모듈을 통합하는 과정에서 오류 및 결함을 찾는 테스트
# - 종류 : 하향식 통합/ 상향식 통합/ 혼합식 통합
#
#
# 사용자 인터페이스의 특징
#
# - 편리성과 가독성 향상
# - 작업 시간 단축
# - 이해도 향상
# - 사용자 중심 설계
#
#
#
# 사용자 인터페이스의 구분
#
# CLI : 텍스트 형태
# GUI : 마우스로 선택하여 작업을 수행
# NU(Natural User Interface) : 말이나 행동으로 기기 조작
#
#
#
# 형상관리
#
# - 소프트웨어의 변경 사항을 관리
# - 관리항목 : 소스 코드/ 프로젝트 계획/ 분석서/ 설계서/지침서/프로그램/테스트케이스
#
#
# 빌드 자동화 도구
#
# - 테스트 및 배포를 자동화하는 도구
# 종류 : Ant/Make/Maven/Gradle/Jenkins
#
#
# C/C++의 데이터 타입과 크기
#
# ![image-5.png](attachment:image-5.png)
#
#
# 상수의 생성
#
# const / #define 예약어 사용
#
#
# 외부 변수
#
# - 변수나 함수를 참조하기 위한 변수
# - 함수가 종료된 뒤에도 값이 소멸하지 않음
#
#
# C언어 논리 연산자
#
# ! : 부정
# && : 모두 참이면 참
# || : 하나라도 참이면 참
#
# 조건 연산자
# - 조건에 따라 서로 다른 수식을 수행
#
# C 언어 연산자 순위
#
#
# ![image-6.png](attachment:image-6.png)
#
#
#
#
# ![image-7.png](attachment:image-7.png)
#
#
#
# ![image-8.png](attachment:image-8.png)
#
#
#
# ![image-9.png](attachment:image-9.png)
#
#
#
# 객체지향 프로그래밍 언어의 종류
#
# - java
#     - 분산 네트워크 환경에 적용
#     - 캡슐화가능  재사용성 높음
# - C++
#     - C 언어에 객체지향 개념 적용
# - Smalltalk
#     - 1세대 객체지향 프로그래밍 언어
#
# JavaScript 프레임워크의 종류
#
# jQuery : 호환성 문제 해결
# React : 메타(META)에서 개발
# Angular : 구글 에서 개발
# Node.js : 인테너세 브라우저 외에도 동작
# Ember : 웹 애플리케이션 기능 제공
#
#
# C언어의 대표적인 표준 라이브러리
#
# - math.h
#  - 수학 함수
#  - 주요함수 : sqrt/pow/abs
#
# - stdlib.h
#  - 자료형 변환 , 난수 발생, 메모리 할당
#  - 주요함수 : atoi/atof/srand/rand/malloc/free
#
#
#
# 결합도
#
# 상호 의존하는 정도
#
# 독립적인 모듈이 되기 위해서는 각 모듈 간의 결합도가 약해야
#
#
# 결합도의 종류(약함<강함) :
#
# 자료 결합도 < 스탬프 결합도 < 제어 결합도 < 외부 결합도 < 공통 결합도 < 내용 결합도
#
#
# - 자료 결합도 :
